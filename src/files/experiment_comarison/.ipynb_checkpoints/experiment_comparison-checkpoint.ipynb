# %% [markdown]
# #  Statistical Significance Testing

# %% [markdown]
# ## Main function

# %%
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.stats.contingency_tables import mcnemar

def find_column(df, method, metric):
    """Find the correct column name for a method and metric"""
    method_variations = {
        "SEAL RAG": ["seal_rag", "SEAL_RAG", "seal"],
        "SELF_RAG": ["self_rag", "SELF_RAG", "selfrag"],
        "CRAG_RAG": ["crag_rag", "CRAG_RAG", "crag"],
        "BASIC_RAG": ["basic_rag", "BASIC_RAG", "basic"]
    }
    
    for col in df.columns:
        for variation in method_variations.get(method, [method.lower()]):
            if variation.lower() in col.lower() and metric.lower() in col.lower():
                return col
    return None

def print_column_detection(df, base_method="SEAL RAG", comparison_methods=None, metrics=None):
    """Print which columns were detected for each method/metric combination"""
    
    if comparison_methods is None:
        comparison_methods = ["SELF_RAG", "CRAG_RAG", "BASIC_RAG"]
    
    if metrics is None:
        metrics = ["final_answer_correct", "precision", "recall", "f1"]
    
    print("🔍 COLUMN DETECTION RESULTS")
    print("=" * 100)
    
    all_methods = [base_method] + comparison_methods
    
    for method in all_methods:
        print(f"\n📊 {method}:")
        print("-" * 80)
        
        for metric in metrics:
            col = find_column(df, method, metric)
            if col:
                print(f"   ✅ {metric:<20} → {col}")
            else:
                print(f"   ❌ {metric:<20} → NOT FOUND")
    
    print("\n" + "=" * 100)

def compare_binary_metrics(method1_results, method2_results, method1_name, method2_name):
    """Compare binary metrics using McNemar's test"""
    
    # Convert to integers (True=1, False=0)
    a1 = [int(x) for x in method1_results]
    a2 = [int(x) for x in method2_results]
    
    # Calculate accuracies
    acc1 = sum(a1) / len(a1)
    acc2 = sum(a2) / len(a2)
    
    # Create contingency table with margins
    contingency_table = pd.crosstab(
        pd.Series(a1, name=method1_name), 
        pd.Series(a2, name=method2_name),
        margins=True
    )
    
    # Run McNemar's test
    try:
        table_for_test = contingency_table.iloc[:-1, :-1]  # Remove margins
        result = mcnemar(table_for_test, exact=False)
        p_value = result.pvalue
    except ValueError:
        p_value = 1.0
    
    # Extract counts
    if contingency_table.shape[0] > 1 and contingency_table.shape[1] > 1:
        both_wrong = contingency_table.iloc[0, 0]
        method2_wins = contingency_table.iloc[0, 1]
        method1_wins = contingency_table.iloc[1, 0]
        both_right = contingency_table.iloc[1, 1]
    else:
        both_wrong = method2_wins = method1_wins = both_right = 0
    
    return {
        'contingency_table': contingency_table,
        'p_value': p_value,
        'is_significant': p_value < 0.05,
        'method1_accuracy': acc1,
        'method2_accuracy': acc2,
        'method1_wins': method1_wins,
        'method2_wins': method2_wins,
        'both_correct': both_right,
        'both_wrong': both_wrong,
        'test_type': 'McNemar',
        'statistic_name': 'Chi-squared',
        'degrees_freedom': 1
    }

def compare_continuous_metrics(method1_values, method2_values, method1_name, method2_name):
    """Compare continuous metrics using paired t-test"""
    
    # Convert to numpy arrays
    values1 = np.array(method1_values)
    values2 = np.array(method2_values)
    
    # Remove NaN values
    mask = ~(np.isnan(values1) | np.isnan(values2))
    values1_clean = values1[mask]
    values2_clean = values2[mask]
    
    if len(values1_clean) == 0:
        return {'error': 'No valid data after removing NaN values'}
    
    # Calculate statistics
    mean1 = np.mean(values1_clean)
    mean2 = np.mean(values2_clean)
    std1 = np.std(values1_clean, ddof=1)
    std2 = np.std(values2_clean, ddof=1)
    
    # Calculate differences
    differences = values1_clean - values2_clean
    mean_diff = np.mean(differences)
    std_diff = np.std(differences, ddof=1)
    
    # Paired t-test
    t_statistic, p_value = stats.ttest_rel(values1_clean, values2_clean)
    
    # Effect size (Cohen's d for paired samples)
    cohen_d = mean_diff / std_diff if std_diff > 0 else 0
    
    return {
        'p_value': p_value,
        'is_significant': p_value < 0.05,
        'mean1': mean1,
        'mean2': mean2,
        'std1': std1,
        'std2': std2,
        'mean_difference': mean_diff,
        'cohen_d': cohen_d,
        't_statistic': t_statistic,
        'n_samples': len(values1_clean),
        'test_type': 'Paired T-test',
        'statistic_name': 'T-statistic',
        'degrees_freedom': len(values1_clean) - 1
    }

def print_contingency_matrix(table, method1_name, method2_name):
    """Print a nicely formatted 2x2 contingency matrix"""
    
    print(f"\n📋 CONTINGENCY MATRIX: {method1_name} vs {method2_name}")
    print("=" * 60)
    
    # Remove margins if they exist
    if 'All' in table.index:
        display_table = table.iloc[:-1, :-1]
    else:
        display_table = table
    
    print(f"                    {method2_name}")
    print(f"                 Wrong    Right    Total")
    print("-" * 50)
    
    if display_table.shape[0] >= 2 and display_table.shape[1] >= 2:
        both_wrong = display_table.iloc[0, 0]
        m2_wins = display_table.iloc[0, 1]
        m1_wins = display_table.iloc[1, 0]
        both_right = display_table.iloc[1, 1]
        
        row1_total = both_wrong + m2_wins
        row2_total = m1_wins + both_right
        col1_total = both_wrong + m1_wins
        col2_total = m2_wins + both_right
        grand_total = row1_total + row2_total
        
        print(f"{method1_name:<8} Wrong  {both_wrong:5d}    {m2_wins:5d}    {row1_total:5d}")
        print(f"         Right  {m1_wins:5d}    {both_right:5d}    {row2_total:5d}")
        print("-" * 50)
        print(f"         Total  {col1_total:5d}    {col2_total:5d}    {grand_total:5d}")
        
        print(f"\n🔍 INTERPRETATION:")
        print(f"   Both wrong: {both_wrong:3d} questions")
        print(f"   {method2_name} wins: {m2_wins:3d} questions (when {method1_name} fails)")
        print(f"   {method1_name} wins: {m1_wins:3d} questions (when {method2_name} fails)")
        print(f"   Both right: {both_right:3d} questions")
        print(f"   Disagreements: {m1_wins + m2_wins:3d} questions (key for statistical test)")
        
        if m1_wins + m2_wins > 0:
            if m1_wins > m2_wins:
                ratio = m1_wins / max(m2_wins, 1)
                print(f"   Head-to-head: {method1_name} wins {ratio:.1f}x more often")
            elif m2_wins > m1_wins:
                ratio = m2_wins / max(m1_wins, 1)
                print(f"   Head-to-head: {method2_name} wins {ratio:.1f}x more often")
            else:
                print(f"   Head-to-head: Tied in disagreements")
    else:
        print("   Insufficient data for 2x2 matrix")

def print_continuous_results(result, method1_name, method2_name, metric_name):
    """Print results for continuous metric comparison"""
    
    if 'error' in result:
        print(f"❌ ERROR: {result['error']}")
        return
    
    print(f"\n📈 CONTINUOUS METRIC RESULTS:")
    print(f"   {method1_name}: {result['mean1']:.4f} ± {result['std1']:.4f}")
    print(f"   {method2_name}: {result['mean2']:.4f} ± {result['std2']:.4f}")
    print(f"   Mean difference: {result['mean_difference']:+.4f}")
    print(f"   Sample size: {result['n_samples']} questions")
    
    print(f"\n📊 PAIRED T-TEST RESULTS:")
    print(f"   T-statistic: {result['t_statistic']:.4f}")
    print(f"   P-value: {result['p_value']:.6f}")
    print(f"   Effect size (Cohen's d): {result['cohen_d']:.4f}")
    
    # Significance
    if result['is_significant']:
        better_method = method1_name if result['mean1'] > result['mean2'] else method2_name
        print(f"   Result: 🟢 SIGNIFICANT - {better_method} is significantly better")
    else:
        print(f"   Result: 🔴 NOT SIGNIFICANT - No significant difference")
    
    # Effect size interpretation
    abs_cohen_d = abs(result['cohen_d'])
    if abs_cohen_d < 0.2:
        effect_size = "negligible"
    elif abs_cohen_d < 0.5:
        effect_size = "small"
    elif abs_cohen_d < 0.8:
        effect_size = "medium"
    else:
        effect_size = "large"
    
    print(f"   Effect size interpretation: {effect_size}")

def create_summary_table(results_dict, base_method, comparison_methods, metrics):
    """Create a comprehensive summary table as a DataFrame"""
    
    metric_display = {
        "final_answer_correct": "Accuracy",
        "precision": "Precision", 
        "recall": "Recall",
        "f1": "F1 Score"
    }
    
    summary_data = []
    
    for comparison_method in comparison_methods:
        for metric in metrics:
            if comparison_method in results_dict and metric in results_dict[comparison_method]:
                result = results_dict[comparison_method][metric]
                
                if 'error' not in result:
                    # Common fields
                    row = {
                        'Base_Method': base_method,
                        'Comparison_Method': comparison_method,
                        'Metric': metric_display.get(metric, metric),
                        'Test_Type': result.get('test_type', 'Unknown'),
                        'Statistic_Name': result.get('statistic_name', 'Unknown'),
                        'P_Value': result['p_value'],
                        'Is_Significant': result['is_significant'],
                        'Significance_Level': 'p < 0.001' if result['p_value'] < 0.001 else 
                                           'p < 0.01' if result['p_value'] < 0.01 else
                                           'p < 0.05' if result['p_value'] < 0.05 else 'Not Significant'
                    }
                    
                    # Metric-specific fields
                    if metric == "final_answer_correct":
                        row.update({
                            'Base_Performance': f"{result['method1_accuracy']:.1%}",
                            'Comparison_Performance': f"{result['method2_accuracy']:.1%}",
                            'Performance_Difference': f"{result['method2_accuracy'] - result['method1_accuracy']:+.1%}",
                            'Base_Wins': result['method1_wins'],
                            'Comparison_Wins': result['method2_wins'],
                            'Effect_Size': 'N/A (Binary)',
                            'Statistic_Value': f"χ² = {result.get('chi_squared', 'N/A')}"
                        })
                    else:
                        better_method = base_method if result['mean1'] > result['mean2'] else comparison_method
                        row.update({
                            'Base_Performance': f"{result['mean1']:.3f}",
                            'Comparison_Performance': f"{result['mean2']:.3f}",
                            'Performance_Difference': f"{result['mean_difference']:+.3f}",
                            'Base_Wins': 'N/A (Continuous)',
                            'Comparison_Wins': 'N/A (Continuous)',
                            'Effect_Size': f"{result['cohen_d']:.3f}",
                            'Statistic_Value': f"t = {result['t_statistic']:.3f}"
                        })
                    
                    summary_data.append(row)
                else:
                    # Error case
                    row = {
                        'Base_Method': base_method,
                        'Comparison_Method': comparison_method,
                        'Metric': metric_display.get(metric, metric),
                        'Test_Type': 'ERROR',
                        'Statistic_Name': 'ERROR',
                        'P_Value': np.nan,
                        'Is_Significant': False,
                        'Significance_Level': 'ERROR',
                        'Base_Performance': 'ERROR',
                        'Comparison_Performance': 'ERROR',
                        'Performance_Difference': 'ERROR',
                        'Base_Wins': 'ERROR',
                        'Comparison_Wins': 'ERROR',
                        'Effect_Size': 'ERROR',
                        'Statistic_Value': 'ERROR'
                    }
                    summary_data.append(row)
    
    return pd.DataFrame(summary_data)

def run_comprehensive_comparison_with_summary(df, base_method="SEAL RAG", comparison_methods=None, metrics=None, 
                                            print_detailed=True, return_summary_table=True):
    """
    Run comprehensive comparison and return summary table
    
    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame containing experiment results
    base_method : str
        Base method to compare others against
    comparison_methods : list
        Methods to compare against base
    metrics : list
        Metrics to analyze
    print_detailed : bool
        Whether to print detailed analysis
    return_summary_table : bool
        Whether to return summary table DataFrame
        
    Returns:
    --------
    dict containing:
        - 'detailed_results': Full results dictionary
        - 'summary_table': Summary DataFrame (if return_summary_table=True)
    """
    
    if comparison_methods is None:
        comparison_methods = ["SELF_RAG", "CRAG_RAG", "BASIC_RAG"]
    
    if metrics is None:
        metrics = ["final_answer_correct", "precision", "recall", "f1"]
    
    if print_detailed:
        print("🚀 COMPREHENSIVE RAG METHOD COMPARISON")
        print("=" * 80)
        print(f"📊 BASE METHOD: {base_method}")
        print("=" * 80)
        
        # Column detection
        print_column_detection(df, base_method, comparison_methods, metrics)
    
    # Store all results
    detailed_results = {}
    
    # Run all comparisons
    for comparison_method in comparison_methods:
        detailed_results[comparison_method] = {}
        
        for metric in metrics:
            # Find columns
            base_col = find_column(df, base_method, metric)
            comp_col = find_column(df, comparison_method, metric)
            
            if base_col is None or comp_col is None:
                detailed_results[comparison_method][metric] = {'error': 'Column not found'}
                continue
            
            # Different handling based on metric type
            if metric == "final_answer_correct":
                # Binary metric
                base_values = df[base_col].astype(bool).tolist()
                comp_values = df[comp_col].astype(bool).tolist()
                
                result = compare_binary_metrics(
                    base_values, comp_values, base_method, comparison_method
                )
                
            else:
                # Continuous metric
                base_values = df[base_col].astype(float)
                comp_values = df[comp_col].astype(float)
                
                result = compare_continuous_metrics(
                    base_values, comp_values, base_method, comparison_method
                )
            
            detailed_results[comparison_method][metric] = result
    
    if print_detailed:
        # Print summary table
        metric_display = {
            "final_answer_correct": "Accuracy",
            "precision": "Precision", 
            "recall": "Recall",
            "f1": "F1 Score"
        }
        
        print(f"\n📋 SUMMARY TABLE - P-VALUES")
        print("-" * 80)
        print(f"{'Metric':<20} {'Test Type':<15} {'vs SELF_RAG':<12} {'vs CRAG_RAG':<12} {'vs BASIC_RAG':<12}")
        print("-" * 80)
        
        for metric in metrics:
            test_type = "McNemar's" if metric == "final_answer_correct" else "T-Test"
            row = f"{metric_display[metric]:<20} {test_type:<15}"
            
            for method in comparison_methods:
                if metric in detailed_results[method]:
                    result = detailed_results[method][metric]
                    if 'error' not in result:
                        p_val = result['p_value']
                        if p_val < 0.001:
                            p_str = "< 0.001***"
                        elif p_val < 0.01:
                            p_str = f"{p_val:.3f}**"
                        elif p_val < 0.05:
                            p_str = f"{p_val:.3f}*"
                        else:
                            p_str = f"{p_val:.3f}"
                        row += f"{p_str:<12}"
                    else:
                        row += f"{'ERROR':<12}"
                else:
                    row += f"{'N/A':<12}"
            print(row)
        
        print("-" * 80)
        print("*** p < 0.001 (highly significant)")
        print("**  p < 0.01  (very significant)")
        print("*   p < 0.05  (significant)")
        
        # Detailed results
        for comparison_method in comparison_methods:
            print(f"\n\n🎯 DETAILED ANALYSIS: {base_method} vs {comparison_method}")
            print("=" * 80)
            
            for metric in metrics:
                print(f"\n📊 METRIC: {metric_display.get(metric, metric).upper()}")
                print("-" * 60)
                
                if metric not in detailed_results[comparison_method]:
                    print("❌ ERROR: Analysis not performed")
                    continue
                    
                result = detailed_results[comparison_method][metric]
                
                if 'error' in result:
                    print(f"❌ ERROR: {result['error']}")
                    continue
                
                # Print column info
                base_col = find_column(df, base_method, metric)
                comp_col = find_column(df, comparison_method, metric)
                print(f"📁 COLUMNS USED:")
                print(f"   {base_method}: {base_col}")
                print(f"   {comparison_method}: {comp_col}")
                
                if metric == "final_answer_correct":
                    # Binary metric results
                    print(f"\n🔍 TEST TYPE: McNemar's Test (Binary Data)")
                    print(f"   {base_method}: {result['method1_accuracy']:.1%} accuracy")
                    print(f"   {comparison_method}: {result['method2_accuracy']:.1%} accuracy")
                    print(f"   Difference: {result['method2_accuracy'] - result['method1_accuracy']:+.1%}")
                    print(f"   P-value: {result['p_value']:.6f}")
                    print(f"   Significant: {'🟢 YES' if result['is_significant'] else '🔴 NO'}")
                    
                    print_contingency_matrix(result['contingency_table'], base_method, comparison_method)
                    
                else:
                    # Continuous metric results
                    print(f"\n🔍 TEST TYPE: Paired T-Test (Continuous Data)")
                    print_continuous_results(result, base_method, comparison_method, metric)
    
    # Create summary table
    output = {'detailed_results': detailed_results}
    
    if return_summary_table:
        summary_table = create_summary_table(detailed_results, base_method, comparison_methods, metrics)
        output['summary_table'] = summary_table
        
        if print_detailed:
            print(f"\n\n📊 SUMMARY TABLE (DataFrame)")
            print("=" * 120)
            print(summary_table.to_string(index=False))
    
    return output

# Main function to use
def analyze_rag_experiments_complete(df, base_method="SEAL RAG", comparison_methods=None, 
                                   metrics=None, print_detailed=True):
    """
    Complete analysis function that returns both detailed results and summary table
    
    Usage:
    ------
    results = analyze_rag_experiments_complete(df)
    
    # Access summary table
    summary_df = results['summary_table']
    
    # Access detailed results
    detailed = results['detailed_results']
    """
    
    return run_comprehensive_comparison_with_summary(
        df=df,
        base_method=base_method,
        comparison_methods=comparison_methods,
        metrics=metrics,
        print_detailed=print_detailed,
        return_summary_table=True
    )

# Usage examples:
# results = analyze_rag_experiments_complete(df)
# summary_table = results['summary_table']
# detailed_results = results['detailed_results']

# Save summary table to CSV
# summary_table.to_csv('rag_comparison_summary.csv', index=False)

# Filter significant results only
# significant_results = summary_table[summary_table['Is_Significant'] == True]

# %% [markdown]
# ## k = 3 | gpt 4o-mini

# %%
df = pd.read_csv("k_3/4_o_mini/basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_self_rag_k_3_model_gpt-4o-mini_v13-309f332c.csv")
df = df.iloc[:, 30:]
df
# Out:
#      self_rag_k_3_model_gpt-4o-mini_v13-309f332c_total_cost  \
# 0                                             0.000645
# 1                                             0.000376
# 2                                             0.000261
# 3                                             0.000234
# 4                                             0.000236
# ..                                                 ...
# 195                                           0.000298
# 196                                           0.000403
# 197                                           0.000923
# 198                                           0.000596
# 199                                           0.000307
#
#      basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_recall  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.5
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.5
# 198                                                0.5
# 199                                                0.5
#
#      crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_recall  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.5
# 3                                                  0.5
# 4                                                  0.5
# ..                                                 ...
# 195                                                1.0
# 196                                                0.5
# 197                                                0.0
# 198                                                0.5
# 199                                                0.5
#
#      seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_recall  \
# 0                                                  0.0
# 1                                                  0.0
# 2                                                  0.5
# 3                                                  0.5
# 4                                                  0.5
# ..                                                 ...
# 195                                                0.5
# 196                                                0.5
# 197                                                0.5
# 198                                                0.0
# 199                                                0.5
#
#      self_rag_k_3_model_gpt-4o-mini_v13-309f332c_recall  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.5
# 3                                                  0.5
# 4                                                  0.5
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.5
# 198                                                0.5
# 199                                                0.5
#
#      basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_precision  \
# 0                                               0.0000
# 1                                               0.6667
# 2                                               0.3333
# 3                                               0.6667
# 4                                               0.6667
# ..                                                 ...
# 195                                             0.6667
# 196                                             0.6667
# 197                                             0.3333
# 198                                             0.3333
# 199                                             0.3333
#
#      crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_precision  \
# 0                                               0.0000
# 1                                               0.6667
# 2                                               0.5000
# 3                                               0.5000
# 4                                               0.5000
# ..                                                 ...
# 195                                             0.6667
# 196                                             0.5000
# 197                                             0.0000
# 198                                             0.5000
# 199                                             0.3333
#
#      seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_precision  \
# 0                                                  0.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                1.0
# 198                                                0.0
# 199                                                1.0
#
#      self_rag_k_3_model_gpt-4o-mini_v13-309f332c_precision  \
# 0                                               0.0000
# 1                                               0.6667
# 2                                               1.0000
# 3                                               1.0000
# 4                                               1.0000
# ..                                                 ...
# 195                                             1.0000
# 196                                             1.0000
# 197                                             1.0000
# 198                                             1.0000
# 199                                             0.3333
#
#      basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  0.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                1.0
# 198                                                0.0
# 199                                                0.0
#
#      self_rag_k_3_model_gpt-4o-mini_v13-309f332c_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_f1  \
# 0                                                0.0
# 1                                                0.8
# 2                                                0.4
# 3                                                0.8
# 4                                                0.8
# ..                                               ...
# 195                                              0.8
# 196                                              0.8
# 197                                              0.4
# 198                                              0.4
# 199                                              0.4
#
#      crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_f1  \
# 0                                               0.0
# 1                                               0.8
# 2                                               0.5
# 3                                               0.5
# 4                                               0.5
# ..                                              ...
# 195                                             0.8
# 196                                             0.5
# 197                                             0.0
# 198                                             0.5
# 199                                             0.4
#
#      seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_f1  \
# 0                                            0.0000
# 1                                            0.0000
# 2                                            0.6667
# 3                                            0.6667
# 4                                            0.6667
# ..                                              ...
# 195                                          0.6667
# 196                                          0.6667
# 197                                          0.6667
# 198                                          0.0000
# 199                                          0.6667
#
#      self_rag_k_3_model_gpt-4o-mini_v13-309f332c_f1
# 0                                            0.0000
# 1                                            0.8000
# 2                                            0.6667
# 3                                            0.6667
# 4                                            0.6667
# ..                                              ...
# 195                                          1.0000
# 196                                          1.0000
# 197                                          0.6667
# 198                                          0.6667
# 199                                          0.4000
#
# [200 rows x 17 columns]

# %%
# Run complete analysis
results = analyze_rag_experiments_complete(df)

# Access the summary table
summary_table = results['summary_table']
print(summary_table)

# Access detailed results
detailed_results = results['detailed_results']

# Save summary to CSV
#summary_table.to_csv('rag_comparison_summary.csv', index=False)

# Filter for significant results only
significant_only = summary_table[summary_table['Is_Significant'] == True]
print("\nSignificant results only:")
print(significant_only)

# Get specific comparison
seal_vs_crag_accuracy = summary_table[
    (summary_table['Comparison_Method'] == 'CRAG_RAG') & 
    (summary_table['Metric'] == 'Accuracy')
]
# Out:
# 🚀 COMPREHENSIVE RAG METHOD COMPARISON
# ================================================================================
# 📊 BASE METHOD: SEAL RAG
# ================================================================================
# 🔍 COLUMN DETECTION RESULTS
# ====================================================================================================
#
# 📊 SEAL RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_final_answer_correct
#    ✅ precision            → seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_precision
#    ✅ recall               → seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_recall
#    ✅ f1                   → seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_f1
#
# 📊 SELF_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → self_rag_k_3_model_gpt-4o-mini_v13-309f332c_final_answer_correct
#    ✅ precision            → self_rag_k_3_model_gpt-4o-mini_v13-309f332c_precision
#    ✅ recall               → self_rag_k_3_model_gpt-4o-mini_v13-309f332c_recall
#    ✅ f1                   → self_rag_k_3_model_gpt-4o-mini_v13-309f332c_f1
#
# 📊 CRAG_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_final_answer_correct
#    ✅ precision            → crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_precision
#    ✅ recall               → crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_recall
#    ✅ f1                   → crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_f1
#
# 📊 BASIC_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_final_answer_correct
#    ✅ precision            → basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_precision
#    ✅ recall               → basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_recall
#    ✅ f1                   → basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_f1
#
# ====================================================================================================
#
# 📋 SUMMARY TABLE - P-VALUES
# --------------------------------------------------------------------------------
# Metric               Test Type       vs SELF_RAG  vs CRAG_RAG  vs BASIC_RAG
# --------------------------------------------------------------------------------
# Accuracy             McNemar's      0.003**     < 0.001***  0.045*
# Precision            T-Test         < 0.001***  < 0.001***  < 0.001***
# Recall               T-Test         0.704       0.004**     < 0.001***
# F1 Score             T-Test         0.074       < 0.001***  0.961
# --------------------------------------------------------------------------------
# *** p < 0.001 (highly significant)
# **  p < 0.01  (very significant)
# *   p < 0.05  (significant)
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs SELF_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_final_answer_correct
#    SELF_RAG: self_rag_k_3_model_gpt-4o-mini_v13-309f332c_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 66.5% accuracy
#    SELF_RAG: 54.5% accuracy
#    Difference: -12.0%
#    P-value: 0.002527
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs SELF_RAG
# ============================================================
#                     SELF_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     50       17       67
#          Right     41       92      133
# --------------------------------------------------
#          Total     91      109      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  50 questions
#    SELF_RAG wins:  17 questions (when SEAL RAG fails)
#    SEAL RAG wins:  41 questions (when SELF_RAG fails)
#    Both right:  92 questions
#    Disagreements:  58 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 2.4x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_precision
#    SELF_RAG: self_rag_k_3_model_gpt-4o-mini_v13-309f332c_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.8067 ± 0.3566
#    SELF_RAG: 0.6633 ± 0.4263
#    Mean difference: +0.1433
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 4.4034
#    P-value: 0.000017
#    Effect size (Cohen's d): 0.3114
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_recall
#    SELF_RAG: self_rag_k_3_model_gpt-4o-mini_v13-309f332c_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.4650 ± 0.2214
#    SELF_RAG: 0.4750 ± 0.3353
#    Mean difference: -0.0100
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: -0.3806
#    P-value: 0.703929
#    Effect size (Cohen's d): -0.0269
#    Result: 🔴 NOT SIGNIFICANT - No significant difference
#    Effect size interpretation: negligible
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_f1
#    SELF_RAG: self_rag_k_3_model_gpt-4o-mini_v13-309f332c_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.5774 ± 0.2476
#    SELF_RAG: 0.5313 ± 0.3398
#    Mean difference: +0.0460
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 1.7991
#    P-value: 0.073516
#    Effect size (Cohen's d): 0.1272
#    Result: 🔴 NOT SIGNIFICANT - No significant difference
#    Effect size interpretation: negligible
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs CRAG_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_final_answer_correct
#    CRAG_RAG: crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 66.5% accuracy
#    CRAG_RAG: 51.5% accuracy
#    Difference: -15.0%
#    P-value: 0.000231
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs CRAG_RAG
# ============================================================
#                     CRAG_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     51       16       67
#          Right     46       87      133
# --------------------------------------------------
#          Total     97      103      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  51 questions
#    CRAG_RAG wins:  16 questions (when SEAL RAG fails)
#    SEAL RAG wins:  46 questions (when CRAG_RAG fails)
#    Both right:  87 questions
#    Disagreements:  62 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 2.9x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_precision
#    CRAG_RAG: crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.8067 ± 0.3566
#    CRAG_RAG: 0.3200 ± 0.2681
#    Mean difference: +0.4867
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 18.2871
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.2931
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_recall
#    CRAG_RAG: crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.4650 ± 0.2214
#    CRAG_RAG: 0.3850 ± 0.3534
#    Mean difference: +0.0800
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 2.8795
#    P-value: 0.004419
#    Effect size (Cohen's d): 0.2036
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_f1
#    CRAG_RAG: crag_rag_k_3_model_gpt-4o-mini_v13-f0d7c078_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.5774 ± 0.2476
#    CRAG_RAG: 0.3460 ± 0.2989
#    Mean difference: +0.2314
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 9.5398
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.6746
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: medium
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs BASIC_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_final_answer_correct
#    BASIC_RAG: basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 66.5% accuracy
#    BASIC_RAG: 59.5% accuracy
#    Difference: -7.0%
#    P-value: 0.044862
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs BASIC_RAG
# ============================================================
#                     BASIC_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     53       14       67
#          Right     28      105      133
# --------------------------------------------------
#          Total     81      119      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  53 questions
#    BASIC_RAG wins:  14 questions (when SEAL RAG fails)
#    SEAL RAG wins:  28 questions (when BASIC_RAG fails)
#    Both right: 105 questions
#    Disagreements:  42 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 2.0x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_precision
#    BASIC_RAG: basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.8067 ± 0.3566
#    BASIC_RAG: 0.4808 ± 0.1907
#    Mean difference: +0.3258
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 14.5290
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.0274
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_recall
#    BASIC_RAG: basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.4650 ± 0.2214
#    BASIC_RAG: 0.7200 ± 0.2864
#    Mean difference: -0.2550
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: -12.5258
#    P-value: 0.000000
#    Effect size (Cohen's d): -0.8857
#    Result: 🟢 SIGNIFICANT - BASIC_RAG is significantly better
#    Effect size interpretation: large
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o-mini_v13-9493c2c0_f1
#    BASIC_RAG: basic_rag_k_3_model_gpt-4o_mini_v30-486b91d1_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.5774 ± 0.2476
#    BASIC_RAG: 0.5765 ± 0.2288
#    Mean difference: +0.0009
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 0.0484
#    P-value: 0.961453
#    Effect size (Cohen's d): 0.0034
#    Result: 🔴 NOT SIGNIFICANT - No significant difference
#    Effect size interpretation: negligible
#
#
# 📊 SUMMARY TABLE (DataFrame)
# ========================================================================================================================
# Base_Method Comparison_Method    Metric     Test_Type Statistic_Name      P_Value  Is_Significant Significance_Level Base_Performance Comparison_Performance Performance_Difference        Base_Wins  Comparison_Wins  Effect_Size Statistic_Value
#    SEAL RAG          SELF_RAG  Accuracy       McNemar    Chi-squared 2.527347e-03            True           p < 0.01            66.5%                  54.5%                 -12.0%               41               17 N/A (Binary)        χ² = N/A
#    SEAL RAG          SELF_RAG Precision Paired T-test    T-statistic 1.738123e-05            True          p < 0.001            0.807                  0.663                 +0.143 N/A (Continuous) N/A (Continuous)        0.311       t = 4.403
#    SEAL RAG          SELF_RAG    Recall Paired T-test    T-statistic 7.039292e-01           False    Not Significant            0.465                  0.475                 -0.010 N/A (Continuous) N/A (Continuous)       -0.027      t = -0.381
#    SEAL RAG          SELF_RAG  F1 Score Paired T-test    T-statistic 7.351600e-02           False    Not Significant            0.577                  0.531                 +0.046 N/A (Continuous) N/A (Continuous)        0.127       t = 1.799
#    SEAL RAG          CRAG_RAG  Accuracy       McNemar    Chi-squared 2.305018e-04            True          p < 0.001            66.5%                  51.5%                 -15.0%               46               16 N/A (Binary)        χ² = N/A
#    SEAL RAG          CRAG_RAG Precision Paired T-test    T-statistic 1.756355e-44            True          p < 0.001            0.807                  0.320                 +0.487 N/A (Continuous) N/A (Continuous)        1.293      t = 18.287
#    SEAL RAG          CRAG_RAG    Recall Paired T-test    T-statistic 4.418569e-03            True           p < 0.01            0.465                  0.385                 +0.080 N/A (Continuous) N/A (Continuous)        0.204       t = 2.880
#    SEAL RAG          CRAG_RAG  F1 Score Paired T-test    T-statistic 5.311781e-18            True          p < 0.001            0.577                  0.346                 +0.231 N/A (Continuous) N/A (Continuous)        0.675       t = 9.540
#    SEAL RAG         BASIC_RAG  Accuracy       McNemar    Chi-squared 4.486227e-02            True           p < 0.05            66.5%                  59.5%                  -7.0%               28               14 N/A (Binary)        χ² = N/A
#    SEAL RAG         BASIC_RAG Precision Paired T-test    T-statistic 4.450657e-33            True          p < 0.001            0.807                  0.481                 +0.326 N/A (Continuous) N/A (Continuous)        1.027      t = 14.529
#    SEAL RAG         BASIC_RAG    Recall Paired T-test    T-statistic 6.403095e-27            True          p < 0.001            0.465                  0.720                 -0.255 N/A (Continuous) N/A (Continuous)       -0.886     t = -12.526
#    SEAL RAG         BASIC_RAG  F1 Score Paired T-test    T-statistic 9.614526e-01           False    Not Significant            0.577                  0.577                 +0.001 N/A (Continuous) N/A (Continuous)        0.003       t = 0.048
#    Base_Method Comparison_Method     Metric      Test_Type Statistic_Name  \
# 0     SEAL RAG          SELF_RAG   Accuracy        McNemar    Chi-squared
# 1     SEAL RAG          SELF_RAG  Precision  Paired T-test    T-statistic
# 2     SEAL RAG          SELF_RAG     Recall  Paired T-test    T-statistic
# 3     SEAL RAG          SELF_RAG   F1 Score  Paired T-test    T-statistic
# 4     SEAL RAG          CRAG_RAG   Accuracy        McNemar    Chi-squared
# 5     SEAL RAG          CRAG_RAG  Precision  Paired T-test    T-statistic
# 6     SEAL RAG          CRAG_RAG     Recall  Paired T-test    T-statistic
# 7     SEAL RAG          CRAG_RAG   F1 Score  Paired T-test    T-statistic
# 8     SEAL RAG         BASIC_RAG   Accuracy        McNemar    Chi-squared
# 9     SEAL RAG         BASIC_RAG  Precision  Paired T-test    T-statistic
# 10    SEAL RAG         BASIC_RAG     Recall  Paired T-test    T-statistic
# 11    SEAL RAG         BASIC_RAG   F1 Score  Paired T-test    T-statistic
#
#          P_Value  Is_Significant Significance_Level Base_Performance  \
# 0   2.527347e-03            True           p < 0.01            66.5%
# 1   1.738123e-05            True          p < 0.001            0.807
# 2   7.039292e-01           False    Not Significant            0.465
# 3   7.351600e-02           False    Not Significant            0.577
# 4   2.305018e-04            True          p < 0.001            66.5%
# 5   1.756355e-44            True          p < 0.001            0.807
# 6   4.418569e-03            True           p < 0.01            0.465
# 7   5.311781e-18            True          p < 0.001            0.577
# 8   4.486227e-02            True           p < 0.05            66.5%
# 9   4.450657e-33            True          p < 0.001            0.807
# 10  6.403095e-27            True          p < 0.001            0.465
# 11  9.614526e-01           False    Not Significant            0.577
#
#    Comparison_Performance Performance_Difference         Base_Wins  \
# 0                   54.5%                 -12.0%                41
# 1                   0.663                 +0.143  N/A (Continuous)
# 2                   0.475                 -0.010  N/A (Continuous)
# 3                   0.531                 +0.046  N/A (Continuous)
# 4                   51.5%                 -15.0%                46
# 5                   0.320                 +0.487  N/A (Continuous)
# 6                   0.385                 +0.080  N/A (Continuous)
# 7                   0.346                 +0.231  N/A (Continuous)
# 8                   59.5%                  -7.0%                28
# 9                   0.481                 +0.326  N/A (Continuous)
# 10                  0.720                 -0.255  N/A (Continuous)
# 11                  0.577                 +0.001  N/A (Continuous)
#
#      Comparison_Wins   Effect_Size Statistic_Value
# 0                 17  N/A (Binary)        χ² = N/A
# 1   N/A (Continuous)         0.311       t = 4.403
# 2   N/A (Continuous)        -0.027      t = -0.381
# 3   N/A (Continuous)         0.127       t = 1.799
# 4                 16  N/A (Binary)        χ² = N/A
# 5   N/A (Continuous)         1.293      t = 18.287
# 6   N/A (Continuous)         0.204       t = 2.880
# 7   N/A (Continuous)         0.675       t = 9.540
# 8                 14  N/A (Binary)        χ² = N/A
# 9   N/A (Continuous)         1.027      t = 14.529
# 10  N/A (Continuous)        -0.886     t = -12.526
# 11  N/A (Continuous)         0.003       t = 0.048
#
# Significant results only:
#    Base_Method Comparison_Method     Metric      Test_Type Statistic_Name  \
# 0     SEAL RAG          SELF_RAG   Accuracy        McNemar    Chi-squared
# 1     SEAL RAG          SELF_RAG  Precision  Paired T-test    T-statistic
# 4     SEAL RAG          CRAG_RAG   Accuracy        McNemar    Chi-squared
# 5     SEAL RAG          CRAG_RAG  Precision  Paired T-test    T-statistic
# 6     SEAL RAG          CRAG_RAG     Recall  Paired T-test    T-statistic
# 7     SEAL RAG          CRAG_RAG   F1 Score  Paired T-test    T-statistic
# 8     SEAL RAG         BASIC_RAG   Accuracy        McNemar    Chi-squared
# 9     SEAL RAG         BASIC_RAG  Precision  Paired T-test    T-statistic
# 10    SEAL RAG         BASIC_RAG     Recall  Paired T-test    T-statistic
#
#          P_Value  Is_Significant Significance_Level Base_Performance  \
# 0   2.527347e-03            True           p < 0.01            66.5%
# 1   1.738123e-05            True          p < 0.001            0.807
# 4   2.305018e-04            True          p < 0.001            66.5%
# 5   1.756355e-44            True          p < 0.001            0.807
# 6   4.418569e-03            True           p < 0.01            0.465
# 7   5.311781e-18            True          p < 0.001            0.577
# 8   4.486227e-02            True           p < 0.05            66.5%
# 9   4.450657e-33            True          p < 0.001            0.807
# 10  6.403095e-27            True          p < 0.001            0.465
#
#    Comparison_Performance Performance_Difference         Base_Wins  \
# 0                   54.5%                 -12.0%                41
# 1                   0.663                 +0.143  N/A (Continuous)
# 4                   51.5%                 -15.0%                46
# 5                   0.320                 +0.487  N/A (Continuous)
# 6                   0.385                 +0.080  N/A (Continuous)
# 7                   0.346                 +0.231  N/A (Continuous)
# 8                   59.5%                  -7.0%                28
# 9                   0.481                 +0.326  N/A (Continuous)
# 10                  0.720                 -0.255  N/A (Continuous)
#
#      Comparison_Wins   Effect_Size Statistic_Value
# 0                 17  N/A (Binary)        χ² = N/A
# 1   N/A (Continuous)         0.311       t = 4.403
# 4                 16  N/A (Binary)        χ² = N/A
# 5   N/A (Continuous)         1.293      t = 18.287
# 6   N/A (Continuous)         0.204       t = 2.880
# 7   N/A (Continuous)         0.675       t = 9.540
# 8                 14  N/A (Binary)        χ² = N/A
# 9   N/A (Continuous)         1.027      t = 14.529
# 10  N/A (Continuous)        -0.886     t = -12.526

# %% [markdown]
# ## k = 3 | gpt 4.1-mini

# %%
df = pd.read_csv("k_3/4_1_mini/basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9.csv")
df = df.iloc[:, 30:]
df
# Out:
#      self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_total_cost  \
# 0                                             0.001773
# 1                                             0.001003
# 2                                             0.002190
# 3                                             0.000731
# 4                                             0.000708
# ..                                                 ...
# 195                                           0.000857
# 196                                           0.001076
# 197                                           0.000804
# 198                                           0.001270
# 199                                           0.000614
#
#      basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                1.0
# 199                                                0.0
#
#      self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_precision  \
# 0                                               0.0000
# 1                                               0.6667
# 2                                               0.3333
# 3                                               0.6667
# 4                                               0.6667
# ..                                                 ...
# 195                                             0.6667
# 196                                             0.6667
# 197                                             0.3333
# 198                                             0.3333
# 199                                             0.3333
#
#      crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_precision  \
# 0                                               0.0000
# 1                                               0.6667
# 2                                               0.0000
# 3                                               0.6667
# 4                                               0.6667
# ..                                                 ...
# 195                                             0.6667
# 196                                             0.6667
# 197                                             0.0000
# 198                                             0.5000
# 199                                             0.3333
#
#      seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_precision  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.5
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                1.0
# 198                                                1.0
# 199                                                0.5
#
#      self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_precision  \
# 0                                               0.0000
# 1                                               0.6667
# 2                                               0.0000
# 3                                               1.0000
# 4                                               1.0000
# ..                                                 ...
# 195                                             1.0000
# 196                                             1.0000
# 197                                             0.0000
# 198                                             1.0000
# 199                                             1.0000
#
#      basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_f1  \
# 0                                                  0.0
# 1                                                  0.8
# 2                                                  0.4
# 3                                                  0.8
# 4                                                  0.8
# ..                                                 ...
# 195                                                0.8
# 196                                                0.8
# 197                                                0.4
# 198                                                0.4
# 199                                                0.4
#
#      crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_f1  \
# 0                                                0.0
# 1                                                0.8
# 2                                                0.0
# 3                                                0.8
# 4                                                0.8
# ..                                               ...
# 195                                              0.8
# 196                                              0.8
# 197                                              0.0
# 198                                              0.5
# 199                                              0.4
#
#      seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_f1  \
# 0                                            0.0000
# 1                                            1.0000
# 2                                            0.5000
# 3                                            0.6667
# 4                                            0.6667
# ..                                              ...
# 195                                          1.0000
# 196                                          1.0000
# 197                                          1.0000
# 198                                          1.0000
# 199                                          0.5000
#
#      self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_f1  \
# 0                                             0.0000
# 1                                             0.8000
# 2                                             0.0000
# 3                                             1.0000
# 4                                             1.0000
# ..                                               ...
# 195                                           1.0000
# 196                                           1.0000
# 197                                           0.0000
# 198                                           0.6667
# 199                                           0.6667
#
#      basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_recall  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.5
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.5
# 198                                                0.5
# 199                                                0.5
#
#      crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_recall  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.5
# 199                                                0.5
#
#      seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_recall  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.5
# 3                                                  0.5
# 4                                                  0.5
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                1.0
# 198                                                1.0
# 199                                                0.5
#
#      self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_recall
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.5
# 199                                                0.5
#
# [200 rows x 17 columns]

# %%
# Run complete analysis
results = analyze_rag_experiments_complete(df)

# Access the summary table
summary_table = results['summary_table']
print(summary_table)

# Access detailed results
detailed_results = results['detailed_results']

# Save summary to CSV
#summary_table.to_csv('rag_comparison_summary.csv', index=False)

# Filter for significant results only
significant_only = summary_table[summary_table['Is_Significant'] == True]
print("\nSignificant results only:")
print(significant_only)

# Get specific comparison
seal_vs_crag_accuracy = summary_table[
    (summary_table['Comparison_Method'] == 'CRAG_RAG') & 
    (summary_table['Metric'] == 'Accuracy')
]
# Out:
# 🚀 COMPREHENSIVE RAG METHOD COMPARISON
# ================================================================================
# 📊 BASE METHOD: SEAL RAG
# ================================================================================
# 🔍 COLUMN DETECTION RESULTS
# ====================================================================================================
#
# 📊 SEAL RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_final_answer_correct
#    ✅ precision            → seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_precision
#    ✅ recall               → seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_recall
#    ✅ f1                   → seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_f1
#
# 📊 SELF_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_final_answer_correct
#    ✅ precision            → self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_precision
#    ✅ recall               → self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_recall
#    ✅ f1                   → self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_f1
#
# 📊 CRAG_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_final_answer_correct
#    ✅ precision            → crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_precision
#    ✅ recall               → crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_recall
#    ✅ f1                   → crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_f1
#
# 📊 BASIC_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_final_answer_correct
#    ✅ precision            → basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_precision
#    ✅ recall               → basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_recall
#    ✅ f1                   → basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_f1
#
# ====================================================================================================
#
# 📋 SUMMARY TABLE - P-VALUES
# --------------------------------------------------------------------------------
# Metric               Test Type       vs SELF_RAG  vs CRAG_RAG  vs BASIC_RAG
# --------------------------------------------------------------------------------
# Accuracy             McNemar's      0.002**     < 0.001***  0.001**
# Precision            T-Test         < 0.001***  < 0.001***  < 0.001***
# Recall               T-Test         < 0.001***  < 0.001***  0.002**
# F1 Score             T-Test         < 0.001***  < 0.001***  < 0.001***
# --------------------------------------------------------------------------------
# *** p < 0.001 (highly significant)
# **  p < 0.01  (very significant)
# *   p < 0.05  (significant)
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs SELF_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_final_answer_correct
#    SELF_RAG: self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 74.0% accuracy
#    SELF_RAG: 63.0% accuracy
#    Difference: -11.0%
#    P-value: 0.001960
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs SELF_RAG
# ============================================================
#                     SELF_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     40       12       52
#          Right     34      114      148
# --------------------------------------------------
#          Total     74      126      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  40 questions
#    SELF_RAG wins:  12 questions (when SEAL RAG fails)
#    SEAL RAG wins:  34 questions (when SELF_RAG fails)
#    Both right: 114 questions
#    Disagreements:  46 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 2.8x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_precision
#    SELF_RAG: self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.8675 ± 0.2905
#    SELF_RAG: 0.6833 ± 0.3950
#    Mean difference: +0.1842
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 5.9980
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.4241
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_recall
#    SELF_RAG: self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.6450 ± 0.2948
#    SELF_RAG: 0.5475 ± 0.3458
#    Mean difference: +0.0975
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 3.4467
#    P-value: 0.000692
#    Effect size (Cohen's d): 0.2437
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_f1
#    SELF_RAG: self_rag_k_3_model_gpt-4.1-mini_v16-550b21e9_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7152 ± 0.2633
#    SELF_RAG: 0.5823 ± 0.3317
#    Mean difference: +0.1328
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 5.0814
#    P-value: 0.000001
#    Effect size (Cohen's d): 0.3593
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs CRAG_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_final_answer_correct
#    CRAG_RAG: crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 74.0% accuracy
#    CRAG_RAG: 57.5% accuracy
#    Difference: -16.5%
#    P-value: 0.000023
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs CRAG_RAG
# ============================================================
#                     CRAG_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     40       12       52
#          Right     45      103      148
# --------------------------------------------------
#          Total     85      115      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  40 questions
#    CRAG_RAG wins:  12 questions (when SEAL RAG fails)
#    SEAL RAG wins:  45 questions (when CRAG_RAG fails)
#    Both right: 103 questions
#    Disagreements:  57 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 3.8x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_precision
#    CRAG_RAG: crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.8675 ± 0.2905
#    CRAG_RAG: 0.3775 ± 0.2570
#    Mean difference: +0.4900
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 19.9621
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.4115
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_recall
#    CRAG_RAG: crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.6450 ± 0.2948
#    CRAG_RAG: 0.4825 ± 0.3628
#    Mean difference: +0.1625
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 5.4434
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.3849
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_f1
#    CRAG_RAG: crag_rag_k_3_model_gpt-4.1-mini_v16-9bd5b6be_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7152 ± 0.2633
#    CRAG_RAG: 0.4195 ± 0.2956
#    Mean difference: +0.2957
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 11.8728
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.8395
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs BASIC_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_final_answer_correct
#    BASIC_RAG: basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 74.0% accuracy
#    BASIC_RAG: 62.5% accuracy
#    Difference: -11.5%
#    P-value: 0.001332
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs BASIC_RAG
# ============================================================
#                     BASIC_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     40       12       52
#          Right     35      113      148
# --------------------------------------------------
#          Total     75      125      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  40 questions
#    BASIC_RAG wins:  12 questions (when SEAL RAG fails)
#    SEAL RAG wins:  35 questions (when BASIC_RAG fails)
#    Both right: 113 questions
#    Disagreements:  47 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 2.9x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_precision
#    BASIC_RAG: basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.8675 ± 0.2905
#    BASIC_RAG: 0.4808 ± 0.1907
#    Mean difference: +0.3867
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 19.6012
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.3860
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_recall
#    BASIC_RAG: basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.6450 ± 0.2948
#    BASIC_RAG: 0.7200 ± 0.2864
#    Mean difference: -0.0750
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: -3.0948
#    P-value: 0.002253
#    Effect size (Cohen's d): -0.2188
#    Result: 🟢 SIGNIFICANT - BASIC_RAG is significantly better
#    Effect size interpretation: small
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1-mini_v2-c1c5278c_f1
#    BASIC_RAG: basic_rag_k_3_model_gpt-4.1-mini_loop_max_0_v1-68ac1071_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7152 ± 0.2633
#    BASIC_RAG: 0.5765 ± 0.2288
#    Mean difference: +0.1387
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 7.0481
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.4984
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
#
# 📊 SUMMARY TABLE (DataFrame)
# ========================================================================================================================
# Base_Method Comparison_Method    Metric     Test_Type Statistic_Name      P_Value  Is_Significant Significance_Level Base_Performance Comparison_Performance Performance_Difference        Base_Wins  Comparison_Wins  Effect_Size Statistic_Value
#    SEAL RAG          SELF_RAG  Accuracy       McNemar    Chi-squared 1.959645e-03            True           p < 0.01            74.0%                  63.0%                 -11.0%               34               12 N/A (Binary)        χ² = N/A
#    SEAL RAG          SELF_RAG Precision Paired T-test    T-statistic 9.274480e-09            True          p < 0.001            0.868                  0.683                 +0.184 N/A (Continuous) N/A (Continuous)        0.424       t = 5.998
#    SEAL RAG          SELF_RAG    Recall Paired T-test    T-statistic 6.923545e-04            True          p < 0.001            0.645                  0.547                 +0.098 N/A (Continuous) N/A (Continuous)        0.244       t = 3.447
#    SEAL RAG          SELF_RAG  F1 Score Paired T-test    T-statistic 8.604111e-07            True          p < 0.001            0.715                  0.582                 +0.133 N/A (Continuous) N/A (Continuous)        0.359       t = 5.081
#    SEAL RAG          CRAG_RAG  Accuracy       McNemar    Chi-squared 2.250146e-05            True          p < 0.001            74.0%                  57.5%                 -16.5%               45               12 N/A (Binary)        χ² = N/A
#    SEAL RAG          CRAG_RAG Precision Paired T-test    T-statistic 2.138168e-49            True          p < 0.001            0.868                  0.378                 +0.490 N/A (Continuous) N/A (Continuous)        1.412      t = 19.962
#    SEAL RAG          CRAG_RAG    Recall Paired T-test    T-statistic 1.528128e-07            True          p < 0.001            0.645                  0.482                 +0.163 N/A (Continuous) N/A (Continuous)        0.385       t = 5.443
#    SEAL RAG          CRAG_RAG  F1 Score Paired T-test    T-statistic 6.289175e-25            True          p < 0.001            0.715                  0.420                 +0.296 N/A (Continuous) N/A (Continuous)        0.840      t = 11.873
#    SEAL RAG         BASIC_RAG  Accuracy       McNemar    Chi-squared 1.331837e-03            True           p < 0.01            74.0%                  62.5%                 -11.5%               35               12 N/A (Binary)        χ² = N/A
#    SEAL RAG         BASIC_RAG Precision Paired T-test    T-statistic 2.388403e-48            True          p < 0.001            0.868                  0.481                 +0.387 N/A (Continuous) N/A (Continuous)        1.386      t = 19.601
#    SEAL RAG         BASIC_RAG    Recall Paired T-test    T-statistic 2.253314e-03            True           p < 0.01            0.645                  0.720                 -0.075 N/A (Continuous) N/A (Continuous)       -0.219      t = -3.095
#    SEAL RAG         BASIC_RAG  F1 Score Paired T-test    T-statistic 2.909885e-11            True          p < 0.001            0.715                  0.577                 +0.139 N/A (Continuous) N/A (Continuous)        0.498       t = 7.048
#    Base_Method Comparison_Method     Metric      Test_Type Statistic_Name  \
# 0     SEAL RAG          SELF_RAG   Accuracy        McNemar    Chi-squared
# 1     SEAL RAG          SELF_RAG  Precision  Paired T-test    T-statistic
# 2     SEAL RAG          SELF_RAG     Recall  Paired T-test    T-statistic
# 3     SEAL RAG          SELF_RAG   F1 Score  Paired T-test    T-statistic
# 4     SEAL RAG          CRAG_RAG   Accuracy        McNemar    Chi-squared
# 5     SEAL RAG          CRAG_RAG  Precision  Paired T-test    T-statistic
# 6     SEAL RAG          CRAG_RAG     Recall  Paired T-test    T-statistic
# 7     SEAL RAG          CRAG_RAG   F1 Score  Paired T-test    T-statistic
# 8     SEAL RAG         BASIC_RAG   Accuracy        McNemar    Chi-squared
# 9     SEAL RAG         BASIC_RAG  Precision  Paired T-test    T-statistic
# 10    SEAL RAG         BASIC_RAG     Recall  Paired T-test    T-statistic
# 11    SEAL RAG         BASIC_RAG   F1 Score  Paired T-test    T-statistic
#
#          P_Value  Is_Significant Significance_Level Base_Performance  \
# 0   1.959645e-03            True           p < 0.01            74.0%
# 1   9.274480e-09            True          p < 0.001            0.868
# 2   6.923545e-04            True          p < 0.001            0.645
# 3   8.604111e-07            True          p < 0.001            0.715
# 4   2.250146e-05            True          p < 0.001            74.0%
# 5   2.138168e-49            True          p < 0.001            0.868
# 6   1.528128e-07            True          p < 0.001            0.645
# 7   6.289175e-25            True          p < 0.001            0.715
# 8   1.331837e-03            True           p < 0.01            74.0%
# 9   2.388403e-48            True          p < 0.001            0.868
# 10  2.253314e-03            True           p < 0.01            0.645
# 11  2.909885e-11            True          p < 0.001            0.715
#
#    Comparison_Performance Performance_Difference         Base_Wins  \
# 0                   63.0%                 -11.0%                34
# 1                   0.683                 +0.184  N/A (Continuous)
# 2                   0.547                 +0.098  N/A (Continuous)
# 3                   0.582                 +0.133  N/A (Continuous)
# 4                   57.5%                 -16.5%                45
# 5                   0.378                 +0.490  N/A (Continuous)
# 6                   0.482                 +0.163  N/A (Continuous)
# 7                   0.420                 +0.296  N/A (Continuous)
# 8                   62.5%                 -11.5%                35
# 9                   0.481                 +0.387  N/A (Continuous)
# 10                  0.720                 -0.075  N/A (Continuous)
# 11                  0.577                 +0.139  N/A (Continuous)
#
#      Comparison_Wins   Effect_Size Statistic_Value
# 0                 12  N/A (Binary)        χ² = N/A
# 1   N/A (Continuous)         0.424       t = 5.998
# 2   N/A (Continuous)         0.244       t = 3.447
# 3   N/A (Continuous)         0.359       t = 5.081
# 4                 12  N/A (Binary)        χ² = N/A
# 5   N/A (Continuous)         1.412      t = 19.962
# 6   N/A (Continuous)         0.385       t = 5.443
# 7   N/A (Continuous)         0.840      t = 11.873
# 8                 12  N/A (Binary)        χ² = N/A
# 9   N/A (Continuous)         1.386      t = 19.601
# 10  N/A (Continuous)        -0.219      t = -3.095
# 11  N/A (Continuous)         0.498       t = 7.048
#
# Significant results only:
#    Base_Method Comparison_Method     Metric      Test_Type Statistic_Name  \
# 0     SEAL RAG          SELF_RAG   Accuracy        McNemar    Chi-squared
# 1     SEAL RAG          SELF_RAG  Precision  Paired T-test    T-statistic
# 2     SEAL RAG          SELF_RAG     Recall  Paired T-test    T-statistic
# 3     SEAL RAG          SELF_RAG   F1 Score  Paired T-test    T-statistic
# 4     SEAL RAG          CRAG_RAG   Accuracy        McNemar    Chi-squared
# 5     SEAL RAG          CRAG_RAG  Precision  Paired T-test    T-statistic
# 6     SEAL RAG          CRAG_RAG     Recall  Paired T-test    T-statistic
# 7     SEAL RAG          CRAG_RAG   F1 Score  Paired T-test    T-statistic
# 8     SEAL RAG         BASIC_RAG   Accuracy        McNemar    Chi-squared
# 9     SEAL RAG         BASIC_RAG  Precision  Paired T-test    T-statistic
# 10    SEAL RAG         BASIC_RAG     Recall  Paired T-test    T-statistic
# 11    SEAL RAG         BASIC_RAG   F1 Score  Paired T-test    T-statistic
#
#          P_Value  Is_Significant Significance_Level Base_Performance  \
# 0   1.959645e-03            True           p < 0.01            74.0%
# 1   9.274480e-09            True          p < 0.001            0.868
# 2   6.923545e-04            True          p < 0.001            0.645
# 3   8.604111e-07            True          p < 0.001            0.715
# 4   2.250146e-05            True          p < 0.001            74.0%
# 5   2.138168e-49            True          p < 0.001            0.868
# 6   1.528128e-07            True          p < 0.001            0.645
# 7   6.289175e-25            True          p < 0.001            0.715
# 8   1.331837e-03            True           p < 0.01            74.0%
# 9   2.388403e-48            True          p < 0.001            0.868
# 10  2.253314e-03            True           p < 0.01            0.645
# 11  2.909885e-11            True          p < 0.001            0.715
#
#    Comparison_Performance Performance_Difference         Base_Wins  \
# 0                   63.0%                 -11.0%                34
# 1                   0.683                 +0.184  N/A (Continuous)
# 2                   0.547                 +0.098  N/A (Continuous)
# 3                   0.582                 +0.133  N/A (Continuous)
# 4                   57.5%                 -16.5%                45
# 5                   0.378                 +0.490  N/A (Continuous)
# 6                   0.482                 +0.163  N/A (Continuous)
# 7                   0.420                 +0.296  N/A (Continuous)
# 8                   62.5%                 -11.5%                35
# 9                   0.481                 +0.387  N/A (Continuous)
# 10                  0.720                 -0.075  N/A (Continuous)
# 11                  0.577                 +0.139  N/A (Continuous)
#
#      Comparison_Wins   Effect_Size Statistic_Value
# 0                 12  N/A (Binary)        χ² = N/A
# 1   N/A (Continuous)         0.424       t = 5.998
# 2   N/A (Continuous)         0.244       t = 3.447
# 3   N/A (Continuous)         0.359       t = 5.081
# 4                 12  N/A (Binary)        χ² = N/A
# 5   N/A (Continuous)         1.412      t = 19.962
# 6   N/A (Continuous)         0.385       t = 5.443
# 7   N/A (Continuous)         0.840      t = 11.873
# 8                 12  N/A (Binary)        χ² = N/A
# 9   N/A (Continuous)         1.386      t = 19.601
# 10  N/A (Continuous)        -0.219      t = -3.095
# 11  N/A (Continuous)         0.498       t = 7.048

# %% [markdown]
# ## k = 3 | gpt 4o

# %%
df = pd.read_csv("k_3/4o/basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_crag_rag_k_3_model_gpt-4o_v7-4a3469e2_seal_rag_k_3_model_gpt-4o_v13-462cb625_self_rag_k_3_model_gpt-4o_v13-a861cce4.csv")
df = df.iloc[:, 30:]
df
# Out:
#      self_rag_k_3_model_gpt-4o_v13-a861cce4_total_cost  \
# 0                                             0.009168
# 1                                             0.006270
# 2                                             0.013715
# 3                                             0.004570
# 4                                             0.003927
# ..                                                 ...
# 195                                           0.004330
# 196                                           0.007112
# 197                                           0.014190
# 198                                           0.011968
# 199                                           0.005117
#
#      basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_precision  \
# 0                                               0.0000
# 1                                               0.6667
# 2                                               0.3333
# 3                                               0.6667
# 4                                               0.6667
# ..                                                 ...
# 195                                             0.6667
# 196                                             0.6667
# 197                                             0.3333
# 198                                             0.3333
# 199                                             0.3333
#
#      crag_rag_k_3_model_gpt-4o_v7-4a3469e2_precision  \
# 0                                             0.0000
# 1                                             0.6667
# 2                                             0.0000
# 3                                             0.5000
# 4                                             0.5000
# ..                                               ...
# 195                                           0.5000
# 196                                           0.5000
# 197                                           0.0000
# 198                                           0.0000
# 199                                           0.3333
#
#      seal_rag_k_3_model_gpt-4o_v13-462cb625_precision  \
# 0                                              0.0000
# 1                                              1.0000
# 2                                              0.6667
# 3                                              1.0000
# 4                                              1.0000
# ..                                                ...
# 195                                            1.0000
# 196                                            1.0000
# 197                                            1.0000
# 198                                            1.0000
# 199                                            1.0000
#
#      self_rag_k_3_model_gpt-4o_v13-a861cce4_precision  \
# 0                                              0.0000
# 1                                              0.6667
# 2                                              0.0000
# 3                                              1.0000
# 4                                              1.0000
# ..                                                ...
# 195                                            1.0000
# 196                                            1.0000
# 197                                            0.0000
# 198                                            0.0000
# 199                                            0.3333
#
#      basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_wrapper  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#      crag_rag_k_3_model_gpt-4o_v7-4a3469e2_wrapper  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 195                                            NaN
# 196                                            NaN
# 197                                            NaN
# 198                                            NaN
# 199                                            NaN
#
#      seal_rag_k_3_model_gpt-4o_v13-462cb625_wrapper  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 195                                             NaN
# 196                                             NaN
# 197                                             NaN
# 198                                             NaN
# 199                                             NaN
#
#      self_rag_k_3_model_gpt-4o_v13-a861cce4_wrapper  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 195                                             NaN
# 196                                             NaN
# 197                                             NaN
# 198                                             NaN
# 199                                             NaN
#
#      basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_f1  ...  \
# 0                                                  0.0     ...
# 1                                                  0.8     ...
# 2                                                  0.4     ...
# 3                                                  0.8     ...
# 4                                                  0.8     ...
# ..                                                 ...     ...
# 195                                                0.8     ...
# 196                                                0.8     ...
# 197                                                0.4     ...
# 198                                                0.4     ...
# 199                                                0.4     ...
#
#      seal_rag_k_3_model_gpt-4o_v13-462cb625_f1  \
# 0                                       0.0000
# 1                                       1.0000
# 2                                       0.8000
# 3                                       1.0000
# 4                                       0.6667
# ..                                         ...
# 195                                     1.0000
# 196                                     1.0000
# 197                                     1.0000
# 198                                     1.0000
# 199                                     0.6667
#
#      self_rag_k_3_model_gpt-4o_v13-a861cce4_f1  \
# 0                                       0.0000
# 1                                       0.8000
# 2                                       0.0000
# 3                                       1.0000
# 4                                       0.6667
# ..                                         ...
# 195                                     0.6667
# 196                                     1.0000
# 197                                     0.0000
# 198                                     0.0000
# 199                                     0.4000
#
#      basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      crag_rag_k_3_model_gpt-4o_v7-4a3469e2_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      seal_rag_k_3_model_gpt-4o_v13-462cb625_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                1.0
# 198                                                1.0
# 199                                                1.0
#
#      self_rag_k_3_model_gpt-4o_v13-a861cce4_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                1.0
# 198                                                0.0
# 199                                                0.0
#
#      basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_recall  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.5
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.5
# 198                                                0.5
# 199                                                0.5
#
#      crag_rag_k_3_model_gpt-4o_v7-4a3469e2_recall  \
# 0                                             0.0
# 1                                             1.0
# 2                                             0.0
# 3                                             0.5
# 4                                             0.5
# ..                                            ...
# 195                                           0.5
# 196                                           0.5
# 197                                           0.0
# 198                                           0.0
# 199                                           0.5
#
#      seal_rag_k_3_model_gpt-4o_v13-462cb625_recall  \
# 0                                              0.0
# 1                                              1.0
# 2                                              1.0
# 3                                              1.0
# 4                                              0.5
# ..                                             ...
# 195                                            1.0
# 196                                            1.0
# 197                                            1.0
# 198                                            1.0
# 199                                            0.5
#
#      self_rag_k_3_model_gpt-4o_v13-a861cce4_recall
# 0                                              0.0
# 1                                              1.0
# 2                                              0.0
# 3                                              1.0
# 4                                              0.5
# ..                                             ...
# 195                                            0.5
# 196                                            1.0
# 197                                            0.0
# 198                                            0.0
# 199                                            0.5
#
# [200 rows x 21 columns]

# %%
# Run complete analysis
results = analyze_rag_experiments_complete(df)

# Access the summary table
summary_table = results['summary_table']
print(summary_table)

# Access detailed results
detailed_results = results['detailed_results']

# Save summary to CSV
#summary_table.to_csv('rag_comparison_summary.csv', index=False)

# Filter for significant results only
significant_only = summary_table[summary_table['Is_Significant'] == True]
print("\nSignificant results only:")
print(significant_only)

# Get specific comparison
seal_vs_crag_accuracy = summary_table[
    (summary_table['Comparison_Method'] == 'CRAG_RAG') & 
    (summary_table['Metric'] == 'Accuracy')
]
# Out:
# 🚀 COMPREHENSIVE RAG METHOD COMPARISON
# ================================================================================
# 📊 BASE METHOD: SEAL RAG
# ================================================================================
# 🔍 COLUMN DETECTION RESULTS
# ====================================================================================================
#
# 📊 SEAL RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → seal_rag_k_3_model_gpt-4o_v13-462cb625_final_answer_correct
#    ✅ precision            → seal_rag_k_3_model_gpt-4o_v13-462cb625_precision
#    ✅ recall               → seal_rag_k_3_model_gpt-4o_v13-462cb625_recall
#    ✅ f1                   → seal_rag_k_3_model_gpt-4o_v13-462cb625_f1
#
# 📊 SELF_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → self_rag_k_3_model_gpt-4o_v13-a861cce4_final_answer_correct
#    ✅ precision            → self_rag_k_3_model_gpt-4o_v13-a861cce4_precision
#    ✅ recall               → self_rag_k_3_model_gpt-4o_v13-a861cce4_recall
#    ✅ f1                   → self_rag_k_3_model_gpt-4o_v13-a861cce4_f1
#
# 📊 CRAG_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → crag_rag_k_3_model_gpt-4o_v7-4a3469e2_final_answer_correct
#    ✅ precision            → crag_rag_k_3_model_gpt-4o_v7-4a3469e2_precision
#    ✅ recall               → crag_rag_k_3_model_gpt-4o_v7-4a3469e2_recall
#    ✅ f1                   → crag_rag_k_3_model_gpt-4o_v7-4a3469e2_f1
#
# 📊 BASIC_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_final_answer_correct
#    ✅ precision            → basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_precision
#    ✅ recall               → basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_recall
#    ✅ f1                   → basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_f1
#
# ====================================================================================================
#
# 📋 SUMMARY TABLE - P-VALUES
# --------------------------------------------------------------------------------
# Metric               Test Type       vs SELF_RAG  vs CRAG_RAG  vs BASIC_RAG
# --------------------------------------------------------------------------------
# Accuracy             McNemar's      0.002**     < 0.001***  < 0.001***
# Precision            T-Test         < 0.001***  < 0.001***  < 0.001***
# Recall               T-Test         < 0.001***  < 0.001***  0.414
# F1 Score             T-Test         < 0.001***  < 0.001***  < 0.001***
# --------------------------------------------------------------------------------
# *** p < 0.001 (highly significant)
# **  p < 0.01  (very significant)
# *   p < 0.05  (significant)
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs SELF_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_final_answer_correct
#    SELF_RAG: self_rag_k_3_model_gpt-4o_v13-a861cce4_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 79.0% accuracy
#    SELF_RAG: 69.0% accuracy
#    Difference: -10.0%
#    P-value: 0.001542
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs SELF_RAG
# ============================================================
#                     SELF_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     34        8       42
#          Right     28      130      158
# --------------------------------------------------
#          Total     62      138      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  34 questions
#    SELF_RAG wins:   8 questions (when SEAL RAG fails)
#    SEAL RAG wins:  28 questions (when SELF_RAG fails)
#    Both right: 130 questions
#    Disagreements:  36 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 3.5x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_precision
#    SELF_RAG: self_rag_k_3_model_gpt-4o_v13-a861cce4_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.9038 ± 0.2485
#    SELF_RAG: 0.7450 ± 0.3839
#    Mean difference: +0.1587
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 6.1019
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.4315
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_recall
#    SELF_RAG: self_rag_k_3_model_gpt-4o_v13-a861cce4_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7375 ± 0.2920
#    SELF_RAG: 0.5400 ± 0.3224
#    Mean difference: +0.1975
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 7.5205
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.5318
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: medium
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_f1
#    SELF_RAG: self_rag_k_3_model_gpt-4o_v13-a861cce4_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7912 ± 0.2532
#    SELF_RAG: 0.6003 ± 0.3111
#    Mean difference: +0.1908
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 8.0797
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.5713
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: medium
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs CRAG_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_final_answer_correct
#    CRAG_RAG: crag_rag_k_3_model_gpt-4o_v7-4a3469e2_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 79.0% accuracy
#    CRAG_RAG: 59.0% accuracy
#    Difference: -20.0%
#    P-value: 0.000000
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs CRAG_RAG
# ============================================================
#                     CRAG_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     35        7       42
#          Right     47      111      158
# --------------------------------------------------
#          Total     82      118      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  35 questions
#    CRAG_RAG wins:   7 questions (when SEAL RAG fails)
#    SEAL RAG wins:  47 questions (when CRAG_RAG fails)
#    Both right: 111 questions
#    Disagreements:  54 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 6.7x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_precision
#    CRAG_RAG: crag_rag_k_3_model_gpt-4o_v7-4a3469e2_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.9038 ± 0.2485
#    CRAG_RAG: 0.3683 ± 0.2515
#    Mean difference: +0.5354
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 24.8111
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.7544
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_recall
#    CRAG_RAG: crag_rag_k_3_model_gpt-4o_v7-4a3469e2_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7375 ± 0.2920
#    CRAG_RAG: 0.4450 ± 0.3392
#    Mean difference: +0.2925
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 9.9872
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.7062
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: medium
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_f1
#    CRAG_RAG: crag_rag_k_3_model_gpt-4o_v7-4a3469e2_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7912 ± 0.2532
#    CRAG_RAG: 0.3990 ± 0.2827
#    Mean difference: +0.3922
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 16.2993
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.1525
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs BASIC_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_final_answer_correct
#    BASIC_RAG: basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 79.0% accuracy
#    BASIC_RAG: 67.5% accuracy
#    Difference: -11.5%
#    P-value: 0.000200
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs BASIC_RAG
# ============================================================
#                     BASIC_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     36        6       42
#          Right     29      129      158
# --------------------------------------------------
#          Total     65      135      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  36 questions
#    BASIC_RAG wins:   6 questions (when SEAL RAG fails)
#    SEAL RAG wins:  29 questions (when BASIC_RAG fails)
#    Both right: 129 questions
#    Disagreements:  35 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 4.8x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_precision
#    BASIC_RAG: basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.9038 ± 0.2485
#    BASIC_RAG: 0.4808 ± 0.1907
#    Mean difference: +0.4229
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 23.4378
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.6573
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_recall
#    BASIC_RAG: basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7375 ± 0.2920
#    BASIC_RAG: 0.7200 ± 0.2864
#    Mean difference: +0.0175
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 0.8186
#    P-value: 0.413987
#    Effect size (Cohen's d): 0.0579
#    Result: 🔴 NOT SIGNIFICANT - No significant difference
#    Effect size interpretation: negligible
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4o_v13-462cb625_f1
#    BASIC_RAG: basic_rag_k_3_model_gpt-4o_loop_max_0_v1-0fe72ad7_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7912 ± 0.2532
#    BASIC_RAG: 0.5765 ± 0.2288
#    Mean difference: +0.2147
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 12.0873
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.8547
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
#
# 📊 SUMMARY TABLE (DataFrame)
# ========================================================================================================================
# Base_Method Comparison_Method    Metric     Test_Type Statistic_Name      P_Value  Is_Significant Significance_Level Base_Performance Comparison_Performance Performance_Difference        Base_Wins  Comparison_Wins  Effect_Size Statistic_Value
#    SEAL RAG          SELF_RAG  Accuracy       McNemar    Chi-squared 1.541970e-03            True           p < 0.01            79.0%                  69.0%                 -10.0%               28                8 N/A (Binary)        χ² = N/A
#    SEAL RAG          SELF_RAG Precision Paired T-test    T-statistic 5.380049e-09            True          p < 0.001            0.904                  0.745                 +0.159 N/A (Continuous) N/A (Continuous)        0.431       t = 6.102
#    SEAL RAG          SELF_RAG    Recall Paired T-test    T-statistic 1.831599e-12            True          p < 0.001            0.738                  0.540                 +0.198 N/A (Continuous) N/A (Continuous)        0.532       t = 7.521
#    SEAL RAG          SELF_RAG  F1 Score Paired T-test    T-statistic 6.160407e-14            True          p < 0.001            0.791                  0.600                 +0.191 N/A (Continuous) N/A (Continuous)        0.571       t = 8.080
#    SEAL RAG          CRAG_RAG  Accuracy       McNemar    Chi-squared 1.113051e-07            True          p < 0.001            79.0%                  59.0%                 -20.0%               47                7 N/A (Binary)        χ² = N/A
#    SEAL RAG          CRAG_RAG Precision Paired T-test    T-statistic 8.119539e-63            True          p < 0.001            0.904                  0.368                 +0.535 N/A (Continuous) N/A (Continuous)        1.754      t = 24.811
#    SEAL RAG          CRAG_RAG    Recall Paired T-test    T-statistic 2.688821e-19            True          p < 0.001            0.738                  0.445                 +0.292 N/A (Continuous) N/A (Continuous)        0.706       t = 9.987
#    SEAL RAG          CRAG_RAG  F1 Score Paired T-test    T-statistic 1.686538e-38            True          p < 0.001            0.791                  0.399                 +0.392 N/A (Continuous) N/A (Continuous)        1.153      t = 16.299
#    SEAL RAG         BASIC_RAG  Accuracy       McNemar    Chi-squared 2.002676e-04            True          p < 0.001            79.0%                  67.5%                 -11.5%               29                6 N/A (Binary)        χ² = N/A
#    SEAL RAG         BASIC_RAG Precision Paired T-test    T-statistic 3.818849e-59            True          p < 0.001            0.904                  0.481                 +0.423 N/A (Continuous) N/A (Continuous)        1.657      t = 23.438
#    SEAL RAG         BASIC_RAG    Recall Paired T-test    T-statistic 4.139870e-01           False    Not Significant            0.738                  0.720                 +0.018 N/A (Continuous) N/A (Continuous)        0.058       t = 0.819
#    SEAL RAG         BASIC_RAG  F1 Score Paired T-test    T-statistic 1.398549e-25            True          p < 0.001            0.791                  0.577                 +0.215 N/A (Continuous) N/A (Continuous)        0.855      t = 12.087
#    Base_Method Comparison_Method     Metric      Test_Type Statistic_Name  \
# 0     SEAL RAG          SELF_RAG   Accuracy        McNemar    Chi-squared
# 1     SEAL RAG          SELF_RAG  Precision  Paired T-test    T-statistic
# 2     SEAL RAG          SELF_RAG     Recall  Paired T-test    T-statistic
# 3     SEAL RAG          SELF_RAG   F1 Score  Paired T-test    T-statistic
# 4     SEAL RAG          CRAG_RAG   Accuracy        McNemar    Chi-squared
# 5     SEAL RAG          CRAG_RAG  Precision  Paired T-test    T-statistic
# 6     SEAL RAG          CRAG_RAG     Recall  Paired T-test    T-statistic
# 7     SEAL RAG          CRAG_RAG   F1 Score  Paired T-test    T-statistic
# 8     SEAL RAG         BASIC_RAG   Accuracy        McNemar    Chi-squared
# 9     SEAL RAG         BASIC_RAG  Precision  Paired T-test    T-statistic
# 10    SEAL RAG         BASIC_RAG     Recall  Paired T-test    T-statistic
# 11    SEAL RAG         BASIC_RAG   F1 Score  Paired T-test    T-statistic
#
#          P_Value  Is_Significant Significance_Level Base_Performance  \
# 0   1.541970e-03            True           p < 0.01            79.0%
# 1   5.380049e-09            True          p < 0.001            0.904
# 2   1.831599e-12            True          p < 0.001            0.738
# 3   6.160407e-14            True          p < 0.001            0.791
# 4   1.113051e-07            True          p < 0.001            79.0%
# 5   8.119539e-63            True          p < 0.001            0.904
# 6   2.688821e-19            True          p < 0.001            0.738
# 7   1.686538e-38            True          p < 0.001            0.791
# 8   2.002676e-04            True          p < 0.001            79.0%
# 9   3.818849e-59            True          p < 0.001            0.904
# 10  4.139870e-01           False    Not Significant            0.738
# 11  1.398549e-25            True          p < 0.001            0.791
#
#    Comparison_Performance Performance_Difference         Base_Wins  \
# 0                   69.0%                 -10.0%                28
# 1                   0.745                 +0.159  N/A (Continuous)
# 2                   0.540                 +0.198  N/A (Continuous)
# 3                   0.600                 +0.191  N/A (Continuous)
# 4                   59.0%                 -20.0%                47
# 5                   0.368                 +0.535  N/A (Continuous)
# 6                   0.445                 +0.292  N/A (Continuous)
# 7                   0.399                 +0.392  N/A (Continuous)
# 8                   67.5%                 -11.5%                29
# 9                   0.481                 +0.423  N/A (Continuous)
# 10                  0.720                 +0.018  N/A (Continuous)
# 11                  0.577                 +0.215  N/A (Continuous)
#
#      Comparison_Wins   Effect_Size Statistic_Value
# 0                  8  N/A (Binary)        χ² = N/A
# 1   N/A (Continuous)         0.431       t = 6.102
# 2   N/A (Continuous)         0.532       t = 7.521
# 3   N/A (Continuous)         0.571       t = 8.080
# 4                  7  N/A (Binary)        χ² = N/A
# 5   N/A (Continuous)         1.754      t = 24.811
# 6   N/A (Continuous)         0.706       t = 9.987
# 7   N/A (Continuous)         1.153      t = 16.299
# 8                  6  N/A (Binary)        χ² = N/A
# 9   N/A (Continuous)         1.657      t = 23.438
# 10  N/A (Continuous)         0.058       t = 0.819
# 11  N/A (Continuous)         0.855      t = 12.087
#
# Significant results only:
#    Base_Method Comparison_Method     Metric      Test_Type Statistic_Name  \
# 0     SEAL RAG          SELF_RAG   Accuracy        McNemar    Chi-squared
# 1     SEAL RAG          SELF_RAG  Precision  Paired T-test    T-statistic
# 2     SEAL RAG          SELF_RAG     Recall  Paired T-test    T-statistic
# 3     SEAL RAG          SELF_RAG   F1 Score  Paired T-test    T-statistic
# 4     SEAL RAG          CRAG_RAG   Accuracy        McNemar    Chi-squared
# 5     SEAL RAG          CRAG_RAG  Precision  Paired T-test    T-statistic
# 6     SEAL RAG          CRAG_RAG     Recall  Paired T-test    T-statistic
# 7     SEAL RAG          CRAG_RAG   F1 Score  Paired T-test    T-statistic
# 8     SEAL RAG         BASIC_RAG   Accuracy        McNemar    Chi-squared
# 9     SEAL RAG         BASIC_RAG  Precision  Paired T-test    T-statistic
# 11    SEAL RAG         BASIC_RAG   F1 Score  Paired T-test    T-statistic
#
#          P_Value  Is_Significant Significance_Level Base_Performance  \
# 0   1.541970e-03            True           p < 0.01            79.0%
# 1   5.380049e-09            True          p < 0.001            0.904
# 2   1.831599e-12            True          p < 0.001            0.738
# 3   6.160407e-14            True          p < 0.001            0.791
# 4   1.113051e-07            True          p < 0.001            79.0%
# 5   8.119539e-63            True          p < 0.001            0.904
# 6   2.688821e-19            True          p < 0.001            0.738
# 7   1.686538e-38            True          p < 0.001            0.791
# 8   2.002676e-04            True          p < 0.001            79.0%
# 9   3.818849e-59            True          p < 0.001            0.904
# 11  1.398549e-25            True          p < 0.001            0.791
#
#    Comparison_Performance Performance_Difference         Base_Wins  \
# 0                   69.0%                 -10.0%                28
# 1                   0.745                 +0.159  N/A (Continuous)
# 2                   0.540                 +0.198  N/A (Continuous)
# 3                   0.600                 +0.191  N/A (Continuous)
# 4                   59.0%                 -20.0%                47
# 5                   0.368                 +0.535  N/A (Continuous)
# 6                   0.445                 +0.292  N/A (Continuous)
# 7                   0.399                 +0.392  N/A (Continuous)
# 8                   67.5%                 -11.5%                29
# 9                   0.481                 +0.423  N/A (Continuous)
# 11                  0.577                 +0.215  N/A (Continuous)
#
#      Comparison_Wins   Effect_Size Statistic_Value
# 0                  8  N/A (Binary)        χ² = N/A
# 1   N/A (Continuous)         0.431       t = 6.102
# 2   N/A (Continuous)         0.532       t = 7.521
# 3   N/A (Continuous)         0.571       t = 8.080
# 4                  7  N/A (Binary)        χ² = N/A
# 5   N/A (Continuous)         1.754      t = 24.811
# 6   N/A (Continuous)         0.706       t = 9.987
# 7   N/A (Continuous)         1.153      t = 16.299
# 8                  6  N/A (Binary)        χ² = N/A
# 9   N/A (Continuous)         1.657      t = 23.438
# 11  N/A (Continuous)         0.855      t = 12.087

# %% [markdown]
# ## k = 3 | gpt 4.1

# %%
df = pd.read_csv("k_3/4_1/basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_self_rag_k_3_model_gpt-4.1_v5-bf23140f.csv")
df = df.iloc[:, 30:]
df
# Out:
#      self_rag_k_3_model_gpt-4.1_v5-bf23140f_total_cost  \
# 0                                             0.008626
# 1                                             0.005016
# 2                                             0.004784
# 3                                             0.005658
# 4                                             0.003142
# ..                                                 ...
# 195                                           0.004284
# 196                                           0.005690
# 197                                           0.006352
# 198                                           0.009762
# 199                                           0.004420
#
#      basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_f1  \
# 0                                                  0.0
# 1                                                  0.8
# 2                                                  0.4
# 3                                                  0.8
# 4                                                  0.8
# ..                                                 ...
# 195                                                0.8
# 196                                                0.8
# 197                                                0.4
# 198                                                0.4
# 199                                                0.4
#
#      crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_f1  \
# 0                                           0.0
# 1                                           0.8
# 2                                           0.0
# 3                                           0.8
# 4                                           0.5
# ..                                          ...
# 195                                         0.8
# 196                                         0.5
# 197                                         0.0
# 198                                         0.0
# 199                                         0.4
#
#      seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_f1  \
# 0                                               0.5000
# 1                                               0.6667
# 2                                               0.5000
# 3                                               1.0000
# 4                                               0.6667
# ..                                                 ...
# 195                                             1.0000
# 196                                             1.0000
# 197                                             0.6667
# 198                                             1.0000
# 199                                             0.5000
#
#      self_rag_k_3_model_gpt-4.1_v5-bf23140f_f1  \
# 0                                       0.0000
# 1                                       0.8000
# 2                                       0.6667
# 3                                       1.0000
# 4                                       0.6667
# ..                                         ...
# 195                                     1.0000
# 196                                     1.0000
# 197                                     0.6667
# 198                                     0.0000
# 199                                     0.4000
#
#      basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_recall  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.5
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.5
# 198                                                0.5
# 199                                                0.5
#
#      crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_recall  \
# 0                                               0.0
# 1                                               1.0
# 2                                               0.0
# 3                                               1.0
# 4                                               0.5
# ..                                              ...
# 195                                             1.0
# 196                                             0.5
# 197                                             0.0
# 198                                             0.0
# 199                                             0.5
#
#      seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_recall  \
# 0                                                  0.5
# 1                                                  0.5
# 2                                                  0.5
# 3                                                  1.0
# 4                                                  0.5
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.5
# 198                                                1.0
# 199                                                0.5
#
#      self_rag_k_3_model_gpt-4.1_v5-bf23140f_recall  \
# 0                                              0.0
# 1                                              1.0
# 2                                              0.5
# 3                                              1.0
# 4                                              0.5
# ..                                             ...
# 195                                            1.0
# 196                                            1.0
# 197                                            0.5
# 198                                            0.0
# 199                                            0.5
#
#      basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  0.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                1.0
#
#      seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                1.0
# 198                                                1.0
# 199                                                0.0
#
#      self_rag_k_3_model_gpt-4.1_v5-bf23140f_final_answer_correct  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                0.0
# 198                                                0.0
# 199                                                0.0
#
#      basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_precision  \
# 0                                               0.0000
# 1                                               0.6667
# 2                                               0.3333
# 3                                               0.6667
# 4                                               0.6667
# ..                                                 ...
# 195                                             0.6667
# 196                                             0.6667
# 197                                             0.3333
# 198                                             0.3333
# 199                                             0.3333
#
#      crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_precision  \
# 0                                               0.0000
# 1                                               0.6667
# 2                                               0.0000
# 3                                               0.6667
# 4                                               0.5000
# ..                                                 ...
# 195                                             0.6667
# 196                                             0.5000
# 197                                             0.0000
# 198                                             0.0000
# 199                                             0.3333
#
#      seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_precision  \
# 0                                                  0.5
# 1                                                  1.0
# 2                                                  0.5
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 195                                                1.0
# 196                                                1.0
# 197                                                1.0
# 198                                                1.0
# 199                                                0.5
#
#      self_rag_k_3_model_gpt-4.1_v5-bf23140f_precision
# 0                                              0.0000
# 1                                              0.6667
# 2                                              1.0000
# 3                                              1.0000
# 4                                              1.0000
# ..                                                ...
# 195                                            1.0000
# 196                                            1.0000
# 197                                            1.0000
# 198                                            0.0000
# 199                                            0.3333
#
# [200 rows x 17 columns]

# %%
# Run complete analysis
results = analyze_rag_experiments_complete(df)

# Access the summary table
summary_table = results['summary_table']
print(summary_table)

# Access detailed results
detailed_results = results['detailed_results']

# Save summary to CSV
#summary_table.to_csv('rag_comparison_summary.csv', index=False)

# Filter for significant results only
significant_only = summary_table[summary_table['Is_Significant'] == True]
print("\nSignificant results only:")
print(significant_only)

# Get specific comparison
seal_vs_crag_accuracy = summary_table[
    (summary_table['Comparison_Method'] == 'CRAG_RAG') & 
    (summary_table['Metric'] == 'Accuracy')
]
# Out:
# 🚀 COMPREHENSIVE RAG METHOD COMPARISON
# ================================================================================
# 📊 BASE METHOD: SEAL RAG
# ================================================================================
# 🔍 COLUMN DETECTION RESULTS
# ====================================================================================================
#
# 📊 SEAL RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_final_answer_correct
#    ✅ precision            → seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_precision
#    ✅ recall               → seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_recall
#    ✅ f1                   → seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_f1
#
# 📊 SELF_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → self_rag_k_3_model_gpt-4.1_v5-bf23140f_final_answer_correct
#    ✅ precision            → self_rag_k_3_model_gpt-4.1_v5-bf23140f_precision
#    ✅ recall               → self_rag_k_3_model_gpt-4.1_v5-bf23140f_recall
#    ✅ f1                   → self_rag_k_3_model_gpt-4.1_v5-bf23140f_f1
#
# 📊 CRAG_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_final_answer_correct
#    ✅ precision            → crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_precision
#    ✅ recall               → crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_recall
#    ✅ f1                   → crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_f1
#
# 📊 BASIC_RAG:
# --------------------------------------------------------------------------------
#    ✅ final_answer_correct → basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_final_answer_correct
#    ✅ precision            → basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_precision
#    ✅ recall               → basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_recall
#    ✅ f1                   → basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_f1
#
# ====================================================================================================
#
# 📋 SUMMARY TABLE - P-VALUES
# --------------------------------------------------------------------------------
# Metric               Test Type       vs SELF_RAG  vs CRAG_RAG  vs BASIC_RAG
# --------------------------------------------------------------------------------
# Accuracy             McNemar's      0.118       0.001**     < 0.001***
# Precision            T-Test         < 0.001***  < 0.001***  < 0.001***
# Recall               T-Test         < 0.001***  < 0.001***  0.812
# F1 Score             T-Test         < 0.001***  < 0.001***  < 0.001***
# --------------------------------------------------------------------------------
# *** p < 0.001 (highly significant)
# **  p < 0.01  (very significant)
# *   p < 0.05  (significant)
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs SELF_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_final_answer_correct
#    SELF_RAG: self_rag_k_3_model_gpt-4.1_v5-bf23140f_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 77.0% accuracy
#    SELF_RAG: 71.5% accuracy
#    Difference: -5.5%
#    P-value: 0.118350
#    Significant: 🔴 NO
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs SELF_RAG
# ============================================================
#                     SELF_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     31       15       46
#          Right     26      128      154
# --------------------------------------------------
#          Total     57      143      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  31 questions
#    SELF_RAG wins:  15 questions (when SEAL RAG fails)
#    SEAL RAG wins:  26 questions (when SELF_RAG fails)
#    Both right: 128 questions
#    Disagreements:  41 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 1.7x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_precision
#    SELF_RAG: self_rag_k_3_model_gpt-4.1_v5-bf23140f_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.9117 ± 0.2427
#    SELF_RAG: 0.7700 ± 0.3495
#    Mean difference: +0.1417
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 5.6352
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.3985
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_recall
#    SELF_RAG: self_rag_k_3_model_gpt-4.1_v5-bf23140f_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7250 ± 0.2912
#    SELF_RAG: 0.5975 ± 0.3158
#    Mean difference: +0.1275
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 5.1390
#    P-value: 0.000001
#    Effect size (Cohen's d): 0.3634
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_f1
#    SELF_RAG: self_rag_k_3_model_gpt-4.1_v5-bf23140f_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7857 ± 0.2491
#    SELF_RAG: 0.6430 ± 0.2893
#    Mean difference: +0.1427
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 6.4365
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.4551
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: small
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs CRAG_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_final_answer_correct
#    CRAG_RAG: crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 77.0% accuracy
#    CRAG_RAG: 65.5% accuracy
#    Difference: -11.5%
#    P-value: 0.001332
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs CRAG_RAG
# ============================================================
#                     CRAG_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     34       12       46
#          Right     35      119      154
# --------------------------------------------------
#          Total     69      131      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  34 questions
#    CRAG_RAG wins:  12 questions (when SEAL RAG fails)
#    SEAL RAG wins:  35 questions (when CRAG_RAG fails)
#    Both right: 119 questions
#    Disagreements:  47 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 2.9x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_precision
#    CRAG_RAG: crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.9117 ± 0.2427
#    CRAG_RAG: 0.3917 ± 0.2593
#    Mean difference: +0.5200
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 24.0621
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.7014
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_recall
#    CRAG_RAG: crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7250 ± 0.2912
#    CRAG_RAG: 0.4950 ± 0.3683
#    Mean difference: +0.2300
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 8.1859
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.5788
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: medium
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_f1
#    CRAG_RAG: crag_rag_k_3_model_gpt-4.1_v18-e197e7d7_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7857 ± 0.2491
#    CRAG_RAG: 0.4330 ± 0.2991
#    Mean difference: +0.3527
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 15.1810
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.0735
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
#
# 🎯 DETAILED ANALYSIS: SEAL RAG vs BASIC_RAG
# ================================================================================
#
# 📊 METRIC: ACCURACY
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_final_answer_correct
#    BASIC_RAG: basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_final_answer_correct
#
# 🔍 TEST TYPE: McNemar's Test (Binary Data)
#    SEAL RAG: 77.0% accuracy
#    BASIC_RAG: 63.0% accuracy
#    Difference: -14.0%
#    P-value: 0.000069
#    Significant: 🟢 YES
#
# 📋 CONTINGENCY MATRIX: SEAL RAG vs BASIC_RAG
# ============================================================
#                     BASIC_RAG
#                  Wrong    Right    Total
# --------------------------------------------------
# SEAL RAG Wrong     37        9       46
#          Right     37      117      154
# --------------------------------------------------
#          Total     74      126      200
#
# 🔍 INTERPRETATION:
#    Both wrong:  37 questions
#    BASIC_RAG wins:   9 questions (when SEAL RAG fails)
#    SEAL RAG wins:  37 questions (when BASIC_RAG fails)
#    Both right: 117 questions
#    Disagreements:  46 questions (key for statistical test)
#    Head-to-head: SEAL RAG wins 4.1x more often
#
# 📊 METRIC: PRECISION
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_precision
#    BASIC_RAG: basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_precision
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.9117 ± 0.2427
#    BASIC_RAG: 0.4808 ± 0.1907
#    Mean difference: +0.4308
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 24.7376
#    P-value: 0.000000
#    Effect size (Cohen's d): 1.7492
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
# 📊 METRIC: RECALL
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_recall
#    BASIC_RAG: basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_recall
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7250 ± 0.2912
#    BASIC_RAG: 0.7200 ± 0.2864
#    Mean difference: +0.0050
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 0.2385
#    P-value: 0.811753
#    Effect size (Cohen's d): 0.0169
#    Result: 🔴 NOT SIGNIFICANT - No significant difference
#    Effect size interpretation: negligible
#
# 📊 METRIC: F1 SCORE
# ------------------------------------------------------------
# 📁 COLUMNS USED:
#    SEAL RAG: seal_rag_k_3_model_gpt-4.1_max_loop_10_v1-32485d86_f1
#    BASIC_RAG: basic_rag_k_3_model_gpt-4.1_loop_max_0_v1-31c3a653_f1
#
# 🔍 TEST TYPE: Paired T-Test (Continuous Data)
#
# 📈 CONTINUOUS METRIC RESULTS:
#    SEAL RAG: 0.7857 ± 0.2491
#    BASIC_RAG: 0.5765 ± 0.2288
#    Mean difference: +0.2092
#    Sample size: 200 questions
#
# 📊 PAIRED T-TEST RESULTS:
#    T-statistic: 12.1578
#    P-value: 0.000000
#    Effect size (Cohen's d): 0.8597
#    Result: 🟢 SIGNIFICANT - SEAL RAG is significantly better
#    Effect size interpretation: large
#
#
# 📊 SUMMARY TABLE (DataFrame)
# ========================================================================================================================
# Base_Method Comparison_Method    Metric     Test_Type Statistic_Name      P_Value  Is_Significant Significance_Level Base_Performance Comparison_Performance Performance_Difference        Base_Wins  Comparison_Wins  Effect_Size Statistic_Value
#    SEAL RAG          SELF_RAG  Accuracy       McNemar    Chi-squared 1.183498e-01           False    Not Significant            77.0%                  71.5%                  -5.5%               26               15 N/A (Binary)        χ² = N/A
#    SEAL RAG          SELF_RAG Precision Paired T-test    T-statistic 5.917819e-08            True          p < 0.001            0.912                  0.770                 +0.142 N/A (Continuous) N/A (Continuous)        0.398       t = 5.635
#    SEAL RAG          SELF_RAG    Recall Paired T-test    T-statistic 6.572573e-07            True          p < 0.001            0.725                  0.598                 +0.128 N/A (Continuous) N/A (Continuous)        0.363       t = 5.139
#    SEAL RAG          SELF_RAG  F1 Score Paired T-test    T-statistic 8.949913e-10            True          p < 0.001            0.786                  0.643                 +0.143 N/A (Continuous) N/A (Continuous)        0.455       t = 6.436
#    SEAL RAG          CRAG_RAG  Accuracy       McNemar    Chi-squared 1.331837e-03            True           p < 0.01            77.0%                  65.5%                 -11.5%               35               12 N/A (Binary)        χ² = N/A
#    SEAL RAG          CRAG_RAG Precision Paired T-test    T-statistic 7.936671e-61            True          p < 0.001            0.912                  0.392                 +0.520 N/A (Continuous) N/A (Continuous)        1.701      t = 24.062
#    SEAL RAG          CRAG_RAG    Recall Paired T-test    T-statistic 3.190529e-14            True          p < 0.001            0.725                  0.495                 +0.230 N/A (Continuous) N/A (Continuous)        0.579       t = 8.186
#    SEAL RAG          CRAG_RAG  F1 Score Paired T-test    T-statistic 4.415380e-35            True          p < 0.001            0.786                  0.433                 +0.353 N/A (Continuous) N/A (Continuous)        1.073      t = 15.181
#    SEAL RAG         BASIC_RAG  Accuracy       McNemar    Chi-squared 6.864535e-05            True          p < 0.001            77.0%                  63.0%                 -14.0%               37                9 N/A (Binary)        χ² = N/A
#    SEAL RAG         BASIC_RAG Precision Paired T-test    T-statistic 1.269003e-62            True          p < 0.001            0.912                  0.481                 +0.431 N/A (Continuous) N/A (Continuous)        1.749      t = 24.738
#    SEAL RAG         BASIC_RAG    Recall Paired T-test    T-statistic 8.117531e-01           False    Not Significant            0.725                  0.720                 +0.005 N/A (Continuous) N/A (Continuous)        0.017       t = 0.238
#    SEAL RAG         BASIC_RAG  F1 Score Paired T-test    T-statistic 8.525274e-26            True          p < 0.001            0.786                  0.577                 +0.209 N/A (Continuous) N/A (Continuous)        0.860      t = 12.158
#    Base_Method Comparison_Method     Metric      Test_Type Statistic_Name  \
# 0     SEAL RAG          SELF_RAG   Accuracy        McNemar    Chi-squared
# 1     SEAL RAG          SELF_RAG  Precision  Paired T-test    T-statistic
# 2     SEAL RAG          SELF_RAG     Recall  Paired T-test    T-statistic
# 3     SEAL RAG          SELF_RAG   F1 Score  Paired T-test    T-statistic
# 4     SEAL RAG          CRAG_RAG   Accuracy        McNemar    Chi-squared
# 5     SEAL RAG          CRAG_RAG  Precision  Paired T-test    T-statistic
# 6     SEAL RAG          CRAG_RAG     Recall  Paired T-test    T-statistic
# 7     SEAL RAG          CRAG_RAG   F1 Score  Paired T-test    T-statistic
# 8     SEAL RAG         BASIC_RAG   Accuracy        McNemar    Chi-squared
# 9     SEAL RAG         BASIC_RAG  Precision  Paired T-test    T-statistic
# 10    SEAL RAG         BASIC_RAG     Recall  Paired T-test    T-statistic
# 11    SEAL RAG         BASIC_RAG   F1 Score  Paired T-test    T-statistic
#
#          P_Value  Is_Significant Significance_Level Base_Performance  \
# 0   1.183498e-01           False    Not Significant            77.0%
# 1   5.917819e-08            True          p < 0.001            0.912
# 2   6.572573e-07            True          p < 0.001            0.725
# 3   8.949913e-10            True          p < 0.001            0.786
# 4   1.331837e-03            True           p < 0.01            77.0%
# 5   7.936671e-61            True          p < 0.001            0.912
# 6   3.190529e-14            True          p < 0.001            0.725
# 7   4.415380e-35            True          p < 0.001            0.786
# 8   6.864535e-05            True          p < 0.001            77.0%
# 9   1.269003e-62            True          p < 0.001            0.912
# 10  8.117531e-01           False    Not Significant            0.725
# 11  8.525274e-26            True          p < 0.001            0.786
#
#    Comparison_Performance Performance_Difference         Base_Wins  \
# 0                   71.5%                  -5.5%                26
# 1                   0.770                 +0.142  N/A (Continuous)
# 2                   0.598                 +0.128  N/A (Continuous)
# 3                   0.643                 +0.143  N/A (Continuous)
# 4                   65.5%                 -11.5%                35
# 5                   0.392                 +0.520  N/A (Continuous)
# 6                   0.495                 +0.230  N/A (Continuous)
# 7                   0.433                 +0.353  N/A (Continuous)
# 8                   63.0%                 -14.0%                37
# 9                   0.481                 +0.431  N/A (Continuous)
# 10                  0.720                 +0.005  N/A (Continuous)
# 11                  0.577                 +0.209  N/A (Continuous)
#
#      Comparison_Wins   Effect_Size Statistic_Value
# 0                 15  N/A (Binary)        χ² = N/A
# 1   N/A (Continuous)         0.398       t = 5.635
# 2   N/A (Continuous)         0.363       t = 5.139
# 3   N/A (Continuous)         0.455       t = 6.436
# 4                 12  N/A (Binary)        χ² = N/A
# 5   N/A (Continuous)         1.701      t = 24.062
# 6   N/A (Continuous)         0.579       t = 8.186
# 7   N/A (Continuous)         1.073      t = 15.181
# 8                  9  N/A (Binary)        χ² = N/A
# 9   N/A (Continuous)         1.749      t = 24.738
# 10  N/A (Continuous)         0.017       t = 0.238
# 11  N/A (Continuous)         0.860      t = 12.158
#
# Significant results only:
#    Base_Method Comparison_Method     Metric      Test_Type Statistic_Name  \
# 1     SEAL RAG          SELF_RAG  Precision  Paired T-test    T-statistic
# 2     SEAL RAG          SELF_RAG     Recall  Paired T-test    T-statistic
# 3     SEAL RAG          SELF_RAG   F1 Score  Paired T-test    T-statistic
# 4     SEAL RAG          CRAG_RAG   Accuracy        McNemar    Chi-squared
# 5     SEAL RAG          CRAG_RAG  Precision  Paired T-test    T-statistic
# 6     SEAL RAG          CRAG_RAG     Recall  Paired T-test    T-statistic
# 7     SEAL RAG          CRAG_RAG   F1 Score  Paired T-test    T-statistic
# 8     SEAL RAG         BASIC_RAG   Accuracy        McNemar    Chi-squared
# 9     SEAL RAG         BASIC_RAG  Precision  Paired T-test    T-statistic
# 11    SEAL RAG         BASIC_RAG   F1 Score  Paired T-test    T-statistic
#
#          P_Value  Is_Significant Significance_Level Base_Performance  \
# 1   5.917819e-08            True          p < 0.001            0.912
# 2   6.572573e-07            True          p < 0.001            0.725
# 3   8.949913e-10            True          p < 0.001            0.786
# 4   1.331837e-03            True           p < 0.01            77.0%
# 5   7.936671e-61            True          p < 0.001            0.912
# 6   3.190529e-14            True          p < 0.001            0.725
# 7   4.415380e-35            True          p < 0.001            0.786
# 8   6.864535e-05            True          p < 0.001            77.0%
# 9   1.269003e-62            True          p < 0.001            0.912
# 11  8.525274e-26            True          p < 0.001            0.786
#
#    Comparison_Performance Performance_Difference         Base_Wins  \
# 1                   0.770                 +0.142  N/A (Continuous)
# 2                   0.598                 +0.128  N/A (Continuous)
# 3                   0.643                 +0.143  N/A (Continuous)
# 4                   65.5%                 -11.5%                35
# 5                   0.392                 +0.520  N/A (Continuous)
# 6                   0.495                 +0.230  N/A (Continuous)
# 7                   0.433                 +0.353  N/A (Continuous)
# 8                   63.0%                 -14.0%                37
# 9                   0.481                 +0.431  N/A (Continuous)
# 11                  0.577                 +0.209  N/A (Continuous)
#
#      Comparison_Wins   Effect_Size Statistic_Value
# 1   N/A (Continuous)         0.398       t = 5.635
# 2   N/A (Continuous)         0.363       t = 5.139
# 3   N/A (Continuous)         0.455       t = 6.436
# 4                 12  N/A (Binary)        χ² = N/A
# 5   N/A (Continuous)         1.701      t = 24.062
# 6   N/A (Continuous)         0.579       t = 8.186
# 7   N/A (Continuous)         1.073      t = 15.181
# 8                  9  N/A (Binary)        χ² = N/A
# 9   N/A (Continuous)         1.749      t = 24.738
# 11  N/A (Continuous)         0.860      t = 12.158
